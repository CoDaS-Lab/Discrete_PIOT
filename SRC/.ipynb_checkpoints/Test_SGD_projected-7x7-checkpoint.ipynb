# %%
import sys
import os
sys.path.append('../SRC')
from PIOT_imports import *
import pickle
from tqdm import tqdm
from torch.distributions import Dirichlet
from numpy.random import uniform

# %%
def row_iter(K, b, row_sum):
    return row_sum / torch.matmul(K, torch.transpose(b, 0, -1))

def col_iter(K, a, col_sum):
    return col_sum / torch.matmul(torch.transpose(K, 0, 1), torch.transpose(a, 0, -1))

def sinkhorn_torch_base(K,
                        row_sum,
                        col_sum,
                        num_iter
                        ):
    '''
    Sinkhorn scaling base
    Parameters
    ----------
    mat     : muted torch 2-tensor of shape(n,m)
    row_sum : immuted torch 1-tensor of size n
    col_sum : immuted torch 1-tensor of size m
    epsilon : tolerance of 1-norm on column-sums with rows normalized
    max_iter: maximal iteration steps (multiples of 10)
    Return
    ------
    Sinkhorn scaled matrix 
    '''
    
    a = torch.ones(len(row_sum))
    b = torch.ones(len(col_sum))

    while num_iter:
        a = row_iter(K, b, row_sum)
        b = col_iter(K, a, col_sum)

        num_iter -= 1

    return torch.matmul(torch.matmul(torch.diag(a), K.clone()), torch.diag(b))

def sinkhorn_torch_fix_steps(mat,
                   row_sum=None,
                   col_sum=None,
                   num_iter = 20,

                   # row_check=False, # Not activate for efficiency concern
                  ):
    '''
    Sinkhorn scaling base
    Parameters
    ----------
    mat     : muted torch 2-tensor of shape(n,m)
    row_sum : immuted torch 1-tensor of size n
    col_sum : immuted torch 1-tensor of size m
    epsilon : tolerance of 1-norm on column-sums with rows normalized
    max_iter: maximal iteration steps (multiples of 10)
    row_confident: whether row sums are all nonzeros (to bypass the check for nan-problem)
    col_confident: whether col sums are all nonzeros (to bypass the check for nan-problem)
    data: stores row and col sums during sinkhorn iterations
    Return
    ------
    Sinkhorn scaled matrix (in place, can skip capturing it)
    '''
    n, m = mat.shape
    row_sum = row_sum if row_sum is not None else torch.ones(n, dtype=torch.float64,
                                                             device=mat.device)
    col_sum = col_sum if col_sum is not None else torch.ones(m, dtype=torch.float64,
                                                             device=mat.device)

    # if row_check:
    #     mat[row_sum != 0, col_sum != 0] = sinkhorn_torch_base(mat[row_sum != 0, col_sum != 0],
    #                                                           row_sum[row_sum != 0],
    #                                                           col_sum[col_sum != 0],
    #                                                           epsilon, max_iter)
    # mat[:, col_sum == 0.] = 0.
    # mat[row_sum == 0., :] = 0.
    mat2 = mat.clone()
    mat2[:, col_sum != 0.] = sinkhorn_torch_base(mat2[:, col_sum != 0.],
                                                row_sum,
                                                col_sum[col_sum != 0],
                                                num_iter)
    mat2[:, col_sum == 0.] = 0.

    return mat2

def sinkhorn_loss(K, r, c, L, nr, nc):
    T = sinkhorn_torch_base(K.clone(),
                   row_sum=r,
                   col_sum=c,
                   num_iter = L)
    return ( -torch.log(K)*T ).sum() #+ 0.001*(r*(torch.log(r)-torch.ones(len(r)))).sum() 


def init(nr, nc, mean, std, num_matrices):
    matrices = []

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    #torch.manual_seed(42)
    r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
    #r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
    c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

    for _ in range(num_matrices):
        # Dirichlet ---
        Dir = Dirichlet(0.5*torch.ones((nr, nc)))
        new_mat = Dir.sample()
        
        # Gaussian ---
        #new_mat = torch.normal(mean = mean, std = std, size = (nr, nc))
        #new_mat = torch.normal(mean = mean*torch.ones(nr), std = std)
        #while new_mat.min() < 0.:
        #    new_mat = torch.normal(mean = mean, std = std, size = (nr, nc))     
        
        # Diagonal ---
        #new_mat = torch.diag(new_mat)
        #adds = torch.ones((nr, nc))*1e-15
        #new_mat += adds

        matrices.append(new_mat)

    print(r)
    print(c)
    print(matrices[0])
    print('\n')
    
    return r, c, matrices

# %% [markdown]
# ## Diagonal matrix, uniform initial

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 50

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
#torch.manual_seed(42)
r = torch.tensor([0.5, 1.0, 1.5], requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Diagonal ---
    diag = torch.ones(nr)
    new_mat = torch.diag(diag)
    adds = torch.ones((nr, nc))*1e-15
    new_mat += adds

    matrices.append(new_mat)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print(r.sum().detach().numpy())
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
ax[1].plot(data_r)
ax[1].set_title('Marginal')
fig.tight_layout()
# Out:
# tensor([0.5000, 1.0000, 1.5000], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[1.0000e+00, 1.0000e-15, 1.0000e-15],
#         [1.0000e-15, 1.0000e+00, 1.0000e-15],
#         [1.0000e-15, 1.0000e-15, 1.0000e+00]])
#
#
# Epoch 0
# Loss: 65.23895040346679
# r: tensor([0.9030, 1.0136, 1.0834], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 0.0002778655496058491
# r: tensor([0.9031, 1.0135, 1.0833], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 0.00027164550579072966
# r: tensor([0.9033, 1.0134, 1.0832], requires_grad=True)
# 3.0000002
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 0.0002619898996272241
# r: tensor([0.9036, 1.0133, 1.0831], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 0.0002474471270943468
# r: tensor([0.9041, 1.0130, 1.0829], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 0.00022668769975098257
# r: tensor([0.9048, 1.0127, 1.0825], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 0.00019916775590900215
# r: tensor([0.9058, 1.0122, 1.0821], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 0.00016597662181538908
# r: tensor([0.9071, 1.0115, 1.0814], requires_grad=True)
# 3.0000002
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 0.00013023255735333805
# r: tensor([0.9089, 1.0106, 1.0805], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 9.611603843495686e-05
# r: tensor([0.9110, 1.0095, 1.0794], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 10
# Loss: 6.712025151500711e-05
# r: tensor([0.9135, 1.0083, 1.0782], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 11
# Loss: 4.4817793110496496e-05
# r: tensor([0.9162, 1.0070, 1.0768], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 12
# Loss: 2.894689336585543e-05
# r: tensor([0.9190, 1.0057, 1.0753], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 13
# Loss: 1.827040526336532e-05
# r: tensor([0.9220, 1.0044, 1.0737], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 14
# Loss: 1.1356193368783352e-05
# r: tensor([0.9250, 1.0031, 1.0720], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 15
# Loss: 6.990369044501676e-06
# r: tensor([0.9279, 1.0019, 1.0702], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 16
# Loss: 4.276969953309617e-06
# r: tensor([0.9309, 1.0009, 1.0683], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 17
# Loss: 2.6065073353009893e-06
# r: tensor([0.9337, 1.0001, 1.0662], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 18
# Loss: 1.5848630239290173e-06
# r: tensor([0.9364, 0.9995, 1.0640], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 19
# Loss: 9.62071527776942e-07
# r: tensor([0.9391, 0.9992, 1.0617], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 20
# Loss: 5.837133869590616e-07
# r: tensor([0.9416, 0.9991, 1.0592], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 21
# Loss: 3.538661219604222e-07
# r: tensor([0.9441, 0.9991, 1.0567], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 22
# Loss: 2.1446831699467594e-07
# r: tensor([0.9466, 0.9992, 1.0542], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 23
# Loss: 1.2996594933589734e-07
# r: tensor([0.9491, 0.9992, 1.0517], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 24
# Loss: 7.87855307105012e-08
# r: tensor([0.9516, 0.9993, 1.0491], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 25
# Loss: 4.778560067086879e-08
# r: tensor([0.9541, 0.9994, 1.0466], requires_grad=True)
# 3.0000002
# c: tensor([1., 1., 1.])
#
#
# Epoch 26
# Loss: 2.8999055753931025e-08
# r: tensor([0.9566, 0.9994, 1.0440], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 27
# Loss: 1.7611808386663874e-08
# r: tensor([0.9590, 0.9995, 1.0414], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 28
# Loss: 1.0710851254536191e-08
# r: tensor([0.9615, 0.9996, 1.0389], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 29
# Loss: 6.5259000842088355e-09
# r: tensor([0.9640, 0.9997, 1.0363], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 30
# Loss: 3.983889048514433e-09
# r: tensor([0.9665, 0.9998, 1.0337], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 31
# Loss: 2.439572214379959e-09
# r: tensor([0.9690, 0.9998, 1.0312], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 32
# Loss: 1.5007339546416198e-09
# r: tensor([0.9715, 0.9999, 1.0286], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 33
# Loss: 9.288530240098014e-10
# r: tensor([0.9740, 1.0000, 1.0260], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 34
# Loss: 5.796697488333336e-10
# r: tensor([0.9764, 1.0001, 1.0235], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 35
# Loss: 3.657603408514787e-10
# r: tensor([0.9789, 1.0002, 1.0209], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 36
# Loss: 2.344510917871856e-10
# r: tensor([0.9813, 1.0003, 1.0184], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 37
# Loss: 1.5361394242133924e-10
# r: tensor([0.9836, 1.0004, 1.0160], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 38
# Loss: 1.036888626717615e-10
# r: tensor([0.9859, 1.0004, 1.0137], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 39
# Loss: 7.2748629115129e-11
# r: tensor([0.9880, 1.0004, 1.0116], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 40
# Loss: 5.350590142391004e-11
# r: tensor([0.9899, 1.0004, 1.0096], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 41
# Loss: 4.148841692289476e-11
# r: tensor([0.9916, 1.0004, 1.0080], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 42
# Loss: 3.3950644650216494e-11
# r: tensor([0.9931, 1.0004, 1.0065], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 43
# Loss: 2.9195766653887165e-11
# r: tensor([0.9944, 1.0003, 1.0053], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 44
# Loss: 2.618101202955976e-11
# r: tensor([0.9954, 1.0003, 1.0043], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 45
# Loss: 2.425642412623441e-11
# r: tensor([0.9963, 1.0002, 1.0035], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 46
# Loss: 2.3021033850371096e-11
# r: tensor([0.9970, 1.0002, 1.0029], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 47
# Loss: 2.222336835497503e-11
# r: tensor([0.9975, 1.0001, 1.0023], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 48
# Loss: 2.170544618335362e-11
# r: tensor([0.9980, 1.0001, 1.0019], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 49
# Loss: 2.1367900152188465e-11
# r: tensor([0.9984, 1.0001, 1.0015], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# [0.9983795 1.0000947 1.0015259]
# 3.0

# %% [markdown]
# ## Diagonal matrix, random init [0, 2)

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 50

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
#torch.manual_seed(42)
vec = uniform(low=0, high=2, size=3)
vec = vec/vec.sum()*nr
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Diagonal ---
    diag = torch.ones(nr)
    new_mat = torch.diag(diag)
    adds = torch.ones((nr, nc))*1e-15
    new_mat += adds

    matrices.append(new_mat)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print(r.sum().detach().numpy())
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
ax[1].plot(data_r)
ax[1].set_title('Marginal')
fig.tight_layout()
# Out:
# tensor([0.1113, 0.2134, 2.6753], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[1.0000e+00, 1.0000e-15, 1.0000e-15],
#         [1.0000e-15, 1.0000e+00, 1.0000e-15],
#         [1.0000e-15, 1.0000e-15, 1.0000e+00]])
#
#
# Epoch 0
# Loss: 705.1534196755529
# r: tensor([0.9252, 0.9249, 1.1498], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 0.01584579724294599
# r: tensor([0.9266, 0.9265, 1.1469], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 0.010286475786415394
# r: tensor([0.9281, 0.9282, 1.1437], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 0.0065076803002739325
# r: tensor([0.9297, 0.9299, 1.1404], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 0.0040458948897139635
# r: tensor([0.9313, 0.9317, 1.1370], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 0.0024875660510588204
# r: tensor([0.9329, 0.9335, 1.1335], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 0.0015184923213382717
# r: tensor([0.9346, 0.9353, 1.1300], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 0.0009228028084180551
# r: tensor([0.9364, 0.9371, 1.1265], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 0.0005591997728515707
# r: tensor([0.9381, 0.9389, 1.1230], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 0.00033821741203610145
# r: tensor([0.9398, 0.9407, 1.1194], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 10
# Loss: 0.00020441520587155537
# r: tensor([0.9416, 0.9425, 1.1159], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 11
# Loss: 0.00012347839430049135
# r: tensor([0.9433, 0.9443, 1.1124], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 12
# Loss: 7.456238978420515e-05
# r: tensor([0.9451, 0.9461, 1.1088], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 13
# Loss: 4.498539891528708e-05
# r: tensor([0.9468, 0.9479, 1.1053], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 14
# Loss: 2.7142919179823366e-05
# r: tensor([0.9485, 0.9497, 1.1018], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 15
# Loss: 1.6382106963419574e-05
# r: tensor([0.9503, 0.9514, 1.0983], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 16
# Loss: 9.88729578210723e-06
# r: tensor([0.9520, 0.9532, 1.0948], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 17
# Loss: 5.96599987190416e-06
# r: tensor([0.9538, 0.9550, 1.0912], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 18
# Loss: 3.5979695294230396e-06
# r: tensor([0.9555, 0.9567, 1.0877], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 19
# Loss: 2.1698257572921875e-06
# r: tensor([0.9573, 0.9585, 1.0842], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 20
# Loss: 1.3085604688711783e-06
# r: tensor([0.9590, 0.9602, 1.0807], requires_grad=True)
# 3.0000002
# c: tensor([1., 1., 1.])
#
#
# Epoch 21
# Loss: 7.892510409668319e-07
# r: tensor([0.9608, 0.9620, 1.0772], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 22
# Loss: 4.7598176022844996e-07
# r: tensor([0.9625, 0.9637, 1.0737], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 23
# Loss: 2.8706467891659315e-07
# r: tensor([0.9643, 0.9655, 1.0703], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 24
# Loss: 1.7314245048805077e-07
# r: tensor([0.9660, 0.9672, 1.0668], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 25
# Loss: 1.0442653208819763e-07
# r: tensor([0.9677, 0.9690, 1.0633], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 26
# Loss: 6.298956917172305e-08
# r: tensor([0.9695, 0.9707, 1.0598], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 27
# Loss: 3.799691419836826e-08
# r: tensor([0.9712, 0.9724, 1.0564], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 28
# Loss: 2.2931272658510693e-08
# r: tensor([0.9729, 0.9742, 1.0529], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 29
# Loss: 1.384471118304198e-08
# r: tensor([0.9746, 0.9759, 1.0495], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 30
# Loss: 8.361354247865549e-09
# r: tensor([0.9763, 0.9776, 1.0460], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 31
# Loss: 5.052792642623594e-09
# r: tensor([0.9781, 0.9793, 1.0426], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 32
# Loss: 3.055542823968138e-09
# r: tensor([0.9798, 0.9810, 1.0392], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 33
# Loss: 1.851511262883354e-09
# r: tensor([0.9815, 0.9827, 1.0358], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 34
# Loss: 1.1259162916235632e-09
# r: tensor([0.9832, 0.9844, 1.0324], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 35
# Loss: 6.88479099685696e-10
# r: tensor([0.9848, 0.9861, 1.0291], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 36
# Loss: 4.2471177833305895e-10
# r: tensor([0.9865, 0.9877, 1.0258], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 37
# Loss: 2.6563098725826406e-10
# r: tensor([0.9881, 0.9893, 1.0226], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 38
# Loss: 1.6965027202064248e-10
# r: tensor([0.9896, 0.9908, 1.0196], requires_grad=True)
# 3.0000002
# c: tensor([1., 1., 1.])
#
#
# Epoch 39
# Loss: 1.1167608417878006e-10
# r: tensor([0.9911, 0.9922, 1.0167], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 40
# Loss: 7.661766512033485e-11
# r: tensor([0.9925, 0.9935, 1.0140], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 41
# Loss: 5.533737639125402e-11
# r: tensor([0.9937, 0.9946, 1.0117], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 42
# Loss: 4.234883540306551e-11
# r: tensor([0.9948, 0.9956, 1.0096], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 43
# Loss: 3.4360760276571506e-11
# r: tensor([0.9957, 0.9964, 1.0079], requires_grad=True)
# 2.9999998
# c: tensor([1., 1., 1.])
#
#
# Epoch 44
# Loss: 2.9400795003870633e-11
# r: tensor([0.9965, 0.9971, 1.0064], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 45
# Loss: 2.6289574656763667e-11
# r: tensor([0.9972, 0.9976, 1.0052], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 46
# Loss: 2.431922531734819e-11
# r: tensor([0.9977, 0.9981, 1.0042], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 47
# Loss: 2.306033467479318e-11
# r: tensor([0.9981, 0.9984, 1.0034], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 48
# Loss: 2.224897471662414e-11
# r: tensor([0.9985, 0.9987, 1.0028], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# Epoch 49
# Loss: 2.172256358080535e-11
# r: tensor([0.9988, 0.9990, 1.0023], requires_grad=True)
# 3.0
# c: tensor([1., 1., 1.])
#
#
# [0.9987637  0.99897814 1.0022582 ]
# 3.0

# %% [markdown]
# ## Symmetric cost, uniform init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 30

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
#torch.manual_seed(42)
r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.rand(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Diagonal ---
    diag = torch.ones(nr)
    new_mat = torch.diag(diag)
    for i in range(nr):
        for j in range(nc):
            if i != j:
                new_mat[i][j] = torch.tensor(np.exp(-np.abs(i-j)))

    matrices.append(new_mat)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[1.0000, 0.3679, 0.1353],
#         [0.3679, 1.0000, 0.3679],
#         [0.1353, 0.3679, 1.0000]])
#
#
# Epoch 0
# Loss: 126.95438539981842
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 126.94813001155853
# r: tensor([1.0329, 0.9346, 1.0325], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 126.94976818561554
# r: tensor([1.0388, 0.9246, 1.0366], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 126.94874572753906
# r: tensor([1.0411, 0.9348, 1.0242], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 126.94886922836304
# r: tensor([1.0382, 0.9362, 1.0256], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 126.94882106781006
# r: tensor([1.0359, 0.9362, 1.0279], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 126.94879221916199
# r: tensor([1.0359, 0.9365, 1.0277], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 126.94890975952148
# r: tensor([1.0370, 0.9364, 1.0267], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 126.94897520542145
# r: tensor([1.0374, 0.9360, 1.0266], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 126.94892883300781
# r: tensor([1.0372, 0.9357, 1.0271], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 10
# Loss: 126.94889724254608
# r: tensor([1.0373, 0.9356, 1.0271], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 11
# Loss: 126.94891834259033
# r: tensor([1.0376, 0.9354, 1.0270], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 12
# Loss: 126.94893062114716
# r: tensor([1.0378, 0.9352, 1.0270], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 13
# Loss: 126.94892609119415
# r: tensor([1.0379, 0.9351, 1.0271], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 14
# Loss: 126.9489221572876
# r: tensor([1.0380, 0.9349, 1.0271], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 15
# Loss: 126.94892454147339
# r: tensor([1.0381, 0.9348, 1.0271], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 16
# Loss: 126.94892477989197
# r: tensor([1.0381, 0.9347, 1.0272], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 17
# Loss: 126.94892466068268
# r: tensor([1.0382, 0.9345, 1.0273], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 18
# Loss: 126.94892370700836
# r: tensor([1.0382, 0.9344, 1.0274], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 19
# Loss: 126.94892501831055
# r: tensor([1.0383, 0.9342, 1.0275], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 20
# Loss: 126.94892299175262
# r: tensor([1.0383, 0.9341, 1.0277], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 21
# Loss: 126.9489233493805
# r: tensor([1.0383, 0.9338, 1.0279], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 22
# Loss: 126.94892072677612
# r: tensor([1.0384, 0.9336, 1.0280], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 23
# Loss: 126.94892084598541
# r: tensor([1.0384, 0.9333, 1.0283], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 24
# Loss: 126.9489175081253
# r: tensor([1.0385, 0.9331, 1.0285], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 25
# Loss: 126.94891631603241
# r: tensor([1.0387, 0.9324, 1.0289], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 26
# Loss: 126.94892048835754
# r: tensor([1.0389, 0.9318, 1.0293], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 27
# Loss: 126.94891500473022
# r: tensor([1.0390, 0.9315, 1.0295], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 28
# Loss: 126.94891881942749
# r: tensor([1.0394, 0.9306, 1.0300], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 29
# Loss: 126.94892036914825
# r: tensor([1.0398, 0.9297, 1.0305], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [1.0398494 0.9296613 1.0304892]
# 3.0

# %% [markdown]
# ## Symmetric matrix, random init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 20
lr = 0.01
num_matrices = 100
num_epoch = 30

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
#torch.manual_seed(42)
#r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
vec = uniform(low=0, high=2, size=nr)
vec = vec / vec.sum()*nr
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Diagonal ---
    diag = torch.ones(nr)
    new_mat = torch.diag(diag)
    for i in range(nr):
        for j in range(nc):
            if i != j:
                new_mat[i][j] = torch.tensor(np.exp(-np.abs(i-j)))

    matrices.append(new_mat)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([0.4665, 1.4084, 1.1251], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[1.0000, 0.3679, 0.1353],
#         [0.3679, 1.0000, 0.3679],
#         [0.1353, 0.3679, 1.0000]])
#
#
# Epoch 0
# Loss: 127.476229429245
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 126.94571053981781
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 10
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 11
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 12
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 13
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 14
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 15
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 16
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 17
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 18
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 19
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 20
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 21
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 22
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 23
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 24
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 25
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 26
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 27
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 28
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 29
# Loss: 126.94571018218994
# r: tensor([1.0327, 0.9347, 1.0327], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [1.0326737 0.9346527 1.0326737]
# 3.0

# %% [markdown]
# ## Dirichlet matrix $\alpha$=0.5, uniform init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(42)
r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.rand(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Dirichlet ---
    Dir = Dirichlet(torch.ones(nr, nc)*0.5)
    matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print(r.sum())
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.8314, 0.1669, 0.0017],
#         [0.5758, 0.0419, 0.3822],
#         [0.0191, 0.1045, 0.8764]])
#
#
# Epoch 0
# Loss: 304.18506932258606
# r: tensor([0.9397, 0.9977, 1.0626], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 303.5691913366318
# r: tensor([0.9495, 1.0043, 1.0462], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 303.3952302932739
# r: tensor([0.9498, 1.0026, 1.0476], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 303.400842666626
# r: tensor([0.9506, 1.0030, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 303.38729655742645
# r: tensor([0.9506, 1.0029, 1.0465], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 303.38790678977966
# r: tensor([0.9506, 1.0029, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 303.3866661787033
# r: tensor([0.9506, 1.0029, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 303.38671922683716
# r: tensor([0.9507, 1.0029, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 303.38659596443176
# r: tensor([0.9507, 1.0029, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 303.3865885734558
# r: tensor([0.9507, 1.0029, 1.0464], requires_grad=True)
# tensor(3., grad_fn=<SumBackward0>)
# c: tensor([1., 1., 1.])
#
#
# [0.9506551 1.0029068 1.0464382]
# 3.0

# %% [markdown]
# ## Dirichlet matrix $\alpha$=0.5, random init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 20
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)



device = 'cuda' if torch.cuda.is_available() else 'cpu'
#torch.manual_seed(42)
#r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
vec = uniform(low=0, high=2,size=3)
vec = vec / vec.sum()*nr
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

# matrices = []
# for _ in range(num_matrices):   

#     # Dirichlet ---
#     Dir = Dirichlet(torch.ones(nr, nc)*0.5)
#     matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([0.3368, 2.3567, 0.3065], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.8314, 0.1669, 0.0017],
#         [0.5758, 0.0419, 0.3822],
#         [0.0191, 0.1045, 0.8764]])
#
#
# Epoch 0
# Loss: 312.4153662919998
# r: tensor([0.9464, 1.0204, 1.0332], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 303.1761829853058
# r: tensor([0.9456, 0.9973, 1.0571], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 303.19368827342987
# r: tensor([0.9460, 0.9957, 1.0583], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 303.18706357479095
# r: tensor([0.9463, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 303.18345284461975
# r: tensor([0.9464, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 303.1820991039276
# r: tensor([0.9464, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 303.18162310123444
# r: tensor([0.9465, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 303.181444644928
# r: tensor([0.9465, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 303.1813944578171
# r: tensor([0.9465, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 303.18136394023895
# r: tensor([0.9465, 0.9954, 1.0582], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [0.9464684 0.995379  1.0581527]
# 3.0

# %% [markdown]
# ## Dirichlet matrix $\alpha$=1, uniform init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.rand(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Dirichlet ---
    Dir = Dirichlet(torch.ones(nr, nc))
    matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.0863, 0.5061, 0.4076],
#         [0.2594, 0.3301, 0.4105],
#         [0.2900, 0.6151, 0.0949]])
#
#
# Epoch 0
# Loss: 313.6948211193085
# r: tensor([0.9615, 1.0523, 0.9862], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 313.24960243701935
# r: tensor([0.9607, 1.0522, 0.9871], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 313.21558380126953
# r: tensor([0.9602, 1.0515, 0.9884], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 313.2045383453369
# r: tensor([0.9599, 1.0512, 0.9889], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 313.20070910453796
# r: tensor([0.9599, 1.0510, 0.9891], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 313.19936776161194
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 313.19888865947723
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 313.19872403144836
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 313.1986643075943
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 313.1986439228058
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [0.9598047 1.0509582 0.9892371]
# 3.0

# %% [markdown]
# ## Dirichlet $\alpha$ =1, random init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

#matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
#r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
vec = uniform(low=0, high=2,size=3)
vec = vec/vec.sum()*nr
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

# for _ in range(num_matrices):   

#     # Dirichlet ---
#     Dir = Dirichlet(torch.ones(nr, nc))
#     matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1.1315, 0.2807, 1.5877], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.0863, 0.5061, 0.4076],
#         [0.2594, 0.3301, 0.4105],
#         [0.2900, 0.6151, 0.0949]])
#
#
# Epoch 0
# Loss: 316.2154734134674
# r: tensor([0.9820, 1.0133, 1.0048], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 313.2307084798813
# r: tensor([0.9632, 1.0472, 0.9896], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 313.2097005844116
# r: tensor([0.9606, 1.0507, 0.9887], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 313.20323622226715
# r: tensor([0.9601, 1.0510, 0.9889], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 313.20037508010864
# r: tensor([0.9599, 1.0510, 0.9891], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 313.1992633342743
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 313.19886231422424
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 313.1987119913101
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 313.1986606121063
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 313.19864082336426
# r: tensor([0.9598, 1.0510, 0.9892], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [0.95980513 1.0509583  0.9892366 ]
# 3.0

# %% [markdown]
# ## Dirichlet matrix $\alpha$=2, uniform init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.rand(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Dirichlet ---
    Dir = Dirichlet(torch.ones(nr, nc)*2.0)
    matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.1473, 0.4586, 0.3941],
#         [0.2871, 0.3322, 0.3807],
#         [0.3166, 0.5182, 0.1652]])
#
#
# Epoch 0
# Loss: 319.0650062561035
# r: tensor([0.8921, 1.0337, 1.0742], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 318.85893654823303
# r: tensor([0.8875, 1.0368, 1.0756], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 318.84335565567017
# r: tensor([0.8860, 1.0380, 1.0760], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 318.83861541748047
# r: tensor([0.8855, 1.0384, 1.0761], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 318.83696722984314
# r: tensor([0.8853, 1.0386, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 318.8363780975342
# r: tensor([0.8852, 1.0386, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 318.83616614341736
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 318.83609223365784
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 318.8360631465912
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 318.83604979515076
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [0.8851309 1.0386708 1.0761986]
# 3.0000002

# %% [markdown]
# ## Dirichelt matrix $\alpha$ = 2, random init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

#matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
vec = uniform(low=0,high=2,size=nr)
#r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

# for _ in range(num_matrices):   

#     # Dirichlet ---
#     Dir = Dirichlet(torch.ones(nr, nc))
#     matrices.append(Dir.sample())

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([0.2075, 1.4994, 0.6615], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.1473, 0.4586, 0.3941],
#         [0.2871, 0.3322, 0.3807],
#         [0.3166, 0.5182, 0.1652]])
#
#
# Epoch 0
# Loss: 320.1663501262665
# r: tensor([0.7650, 1.0982, 1.1368], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 318.85692858695984
# r: tensor([0.8516, 1.0522, 1.0962], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 318.83030939102173
# r: tensor([0.8757, 1.0420, 1.0823], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 318.83382964134216
# r: tensor([0.8825, 1.0395, 1.0780], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 318.8354742527008
# r: tensor([0.8844, 1.0389, 1.0767], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 318.83592104911804
# r: tensor([0.8849, 1.0387, 1.0764], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 318.8360254764557
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 318.83604097366333
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 318.836049079895
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 318.8360469341278
# r: tensor([0.8851, 1.0387, 1.0762], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [0.8851286 1.0386716 1.0761998]
# 3.0

# %% [markdown]
# ## Uniform matrix, uniform init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.rand(nr, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Uniform ---
    matrices.append(torch.ones((nr, nc))/nr/nc)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1., 1., 1.], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.1111, 0.1111, 0.1111],
#         [0.1111, 0.1111, 0.1111],
#         [0.1111, 0.1111, 0.1111]])
#
#
# Epoch 0
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 659.1673374176025
# r: tensor([1., 1., 1.], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [1. 1. 1.]
# 3.0

# %% [markdown]
# ## Uniform matrix, random init

# %%
nr, nc = 3, 3
mean, std = 0.3, 1e-1
L = 100
lr = 0.01
num_matrices = 100
num_epoch = 10

# r, c, matrices = init(nr, nc, mean, std, num_matrices)

matrices = []

device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(37)
vec=uniform(low=0,high=2,size=3)
vec = vec/vec.sum()*nr
#r = torch.ones(nr, requires_grad=True, dtype=torch.float, device=device)
r = torch.tensor(vec, requires_grad=True, dtype=torch.float, device=device)
#r = torch.normal(size = (nr,), mean = 1.0, std = 0.01, requires_grad=True, dtype=torch.float, device=device)
#r = torch.tensor([0.1, 0.5, 2.8], requires_grad=True, dtype=torch.float, device=device)
c = torch.ones(nc, requires_grad=False, dtype=torch.float, device=device)

for _ in range(num_matrices):   

    # Uniform ---
    matrices.append(torch.ones((nr, nc))/nr/nc)

print(r)
print(c)
print(matrices[0])
print('\n')

optimizer = torch.optim.RMSprop([r], lr=lr)

data_loss = []
data_r = []
data_c = []

for epoch in range(num_epoch):
    running_loss = 0
    for i in range(len(matrices)):
        loss = sinkhorn_loss(matrices[i].clone(), r, c, L, nr, nc)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            for param in [r, c]:
                param[:] = param.clamp(1e-15, 10)
                param[:] = param / param.sum() * nr
        
        running_loss += loss.item()
        
    data_loss.append(running_loss)
    data_r.append(r.cpu().detach().clone().numpy())
    data_c.append(c.cpu().detach().clone().numpy())
        
    print('Epoch {}'.format(epoch))
    print('Loss: {}'.format(running_loss))
    print('r: {}'.format(r))
    print('c: {}'.format(c))
    print('\n')
    
print(data_r[-1])
print(data_r[-1].sum())

fig, ax = plt.subplots(1, 2, figsize = (10, 5))

ax[0].plot(data_loss)
ax[0].set_title('Loss')
for i in range(len(data_r[0])):
    ax[1].plot([a[i] for a in data_r], label = str(i))
ax[1].set_title('Marginal')
ax[1].legend(bbox_to_anchor=(1.04,1), loc="upper left")
fig.tight_layout()
# Out:
# tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# tensor([1., 1., 1.])
# tensor([[0.1111, 0.1111, 0.1111],
#         [0.1111, 0.1111, 0.1111],
#         [0.1111, 0.1111, 0.1111]])
#
#
# Epoch 0
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 1
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 2
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 3
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 4
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 5
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 6
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 7
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 8
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# Epoch 9
# Loss: 659.1672897338867
# r: tensor([1.0137, 1.1628, 0.8236], requires_grad=True)
# c: tensor([1., 1., 1.])
#
#
# [1.0136784 1.1627512 0.8235704]
# 3.0
