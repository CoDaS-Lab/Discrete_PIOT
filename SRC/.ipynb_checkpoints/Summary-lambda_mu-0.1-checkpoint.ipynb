# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_sgd = {}
data_baseline = {}
for year in range(1991, 2020):
    y_str = str(year)
    with open('./data/loss_lam0p01_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_sgd:
                    data_sgd[year] = []
                team, loss = pickle.load(f)
                data_sgd[year].append((team, loss.item()))
        except EOFError:
            pass

    
    with open('./data/loss-baseline_lam0p01_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_baseline:
                    data_baseline[year] = []
                team, loss = pickle.load(f)
                data_baseline[year].append((team, loss))
        except EOFError:
            pass

# %%
def get_loss(data, name):
    loss = pd.DataFrame()
    for year in range(1991, 2020):
        if len(data[year]) != 0:
            if loss.empty:
                loss = pd.DataFrame.from_dict(data[year])
                loss.columns = ['Team', 'Loss_'+name]
                loss['Year'] = year
            else:
                tmp = pd.DataFrame.from_dict(data[year])
                tmp.columns = ['Team', 'Loss_'+name]
                tmp['Year'] = year        
                loss = pd.concat([loss, tmp])
    return loss

loss_sgd = get_loss(data_sgd, 'SGD')
loss_baseline = get_loss(data_baseline, 'baseline')

# %%
win_rate = pd.DataFrame()
cols = ['Team', 'W/L%']

for year in range(1991, 2020):
    y_str = str(year)

    path1 = '../NBA/data/win_rate/win_rate_W_{}.csv'.format(y_str)
    path2 = '../NBA/data/win_rate/win_rate_E_{}.csv'.format(y_str)

    
    win_rate1 = pd.read_csv(path1)[cols]
    win_rate2 = pd.read_csv(path2)[cols]
    tmp = pd.concat([win_rate1, win_rate2])
    tmp["Year"] = year
    if win_rate.empty:
        win_rate = tmp
    else:
        win_rate = pd.concat([win_rate, tmp])
win_rate = win_rate.merge(loss_sgd, on = ['Team', 'Year'], how = 'right')    
win_rate = win_rate.merge(loss_baseline, on = ['Team', 'Year'], how = 'left')
win_rate
# Out:
#     Team   W/L%  Year      Loss_SGD  Loss_baseline
# 0    ATL  0.524  1991  59694.015625   62963.521996
# 1    BOS  0.683  1991  71764.117188   76985.234946
# 2    CHI  0.744  1991  37483.773438   48524.805924
# 3    CLE  0.402  1991  55023.710938   59323.491337
# 4    DAL  0.341  1991  56972.457031   63840.071179
# ..   ...    ...   ...           ...            ...
# 805  SAC  0.476  2019  62346.910156   71469.062687
# 806  SAS  0.585  2019  69148.101562   78331.622360
# 807  TOR  0.707  2019  73278.000000   76385.267372
# 808  UTA  0.610  2019  36380.132812   41288.806051
# 809  WAS  0.390  2019  80074.453125   81722.449449
#
# [810 rows x 5 columns]

# %%
win_rate['I'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/10000)
win_rate['I_norm'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/np.abs(win_rate['Loss_baseline']))

# %%
win_rate.dropna().sort_values("I")[:20]
# Out:
#     Team   W/L%  Year       Loss_SGD  Loss_baseline         I    I_norm
# 271  UTA  0.671  2000   28037.132812   51564.147610 -2.352701 -0.456267
# 170  HOU  0.695  1997   49236.136719   69102.860262 -1.986672 -0.287495
# 801  ORL  0.512  2019   65811.890625   85644.832276 -1.983294 -0.231572
# 568  MIA  0.707  2011   24723.650391   43920.976223 -1.919733 -0.437088
# 182  SAC  0.415  1997   42797.789062   61780.177344 -1.898239 -0.307257
# 622  NYK  0.659  2013    -372.684204   18430.817214 -1.880350 -1.020221
# 339  DEN  0.207  2003  102390.109375  120531.344078 -1.814123 -0.150511
# 736  MIL  0.512  2017   51293.417969   68475.365650 -1.718195 -0.250922
# 437  PHI  0.463  2006   41257.324219   57820.852389 -1.656353 -0.286463
# 295  PHO  0.622  2001   51114.421875   67513.685762 -1.639926 -0.242903
# 572  ORL  0.634  2011   35433.421875   51390.492684 -1.595707 -0.310506
# 527  NOH  0.598  2009   47925.695312   63859.368909 -1.593367 -0.249512
# 174  MIA  0.744  1997   39024.210938   54623.684078 -1.559947 -0.285581
# 205  MIN  0.549  1998   54034.195312   68803.811489 -1.476962 -0.214663
# 262  MIN  0.610  2000  -10041.000977    4686.936965 -1.472794 -3.142338
# 70   ORL  0.500  1993   72156.101562   86651.605683 -1.449550 -0.167285
# 278  BOS  0.439  2001   53217.011719   67345.817521 -1.412881 -0.209795
# 789  GSW  0.695  2019   83448.531250   97513.967537 -1.406544 -0.144240
# 695  CLE  0.695  2016   35522.472656   49577.509224 -1.405504 -0.283496
# 164  CHI  0.841  1997   40647.402344   54654.994604 -1.400759 -0.256291

# %%
import seaborn as sns
x, y = win_rate['I'], win_rate['W/L%']
sns.kdeplot(x, y, fill=True, levels = 50, thresh=0, cmap = 'Blues')
sns.kdeplot(x, y, fill=False, levels = [0, 0.025, 1], thresh=0, cmap = 'autumn')
plt.show()
# Out:
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize = (10, 6))
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 10, c=win_rate['Year'], cmap='viridis')
sns.kdeplot(x, y, fill=False, levels = [0, 0.025, 1], thresh=0, cmap = 'autumn')
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
#fig.colorbar()
# Out:
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 8)
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
r_sgd = {}
r_baseline = {}
for year in range(1991, 2020):
    y_str = str(year)
    with open('./data/r_lam0p01_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in r_sgd:
                    r_sgd[year] = []
                team, r = pickle.load(f)
                r_sgd[year].append((team, r))
        except EOFError:
            pass

    
    with open('./data/r-baseline_lam0p01_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in r_baseline:
                    r_baseline[year] = []
                team, r = pickle.load(f)
                r_baseline[year].append((team, r))
        except EOFError:
            pass

# %%
r_sgd[2000]
# Out:
# [('ATL',
#   array([0.80495906, 1.1330421 , 0.41381386, 1.0368428 , 0.5093415 ,
#          1.102001  ], dtype=float32)),
#  ('BOS',
#   array([0.7642475 , 0.6166284 , 1.1510608 , 0.96121126, 0.78322685,
#          0.72362494], dtype=float32)),
#  ('CHI', array([1.2363734, 2.243788 , 1.5198387], dtype=float32)),
#  ('CLE',
#   array([0.630483  , 0.6885254 , 0.83478963, 0.75549954, 0.53457934,
#          0.85395366, 0.70216966], dtype=float32)),
#  ('DAL', array([1.5331715, 0.9330572, 1.2403982, 1.2933729], dtype=float32)),
#  ('DEN',
#   array([0.91354203, 1.3583745 , 1.4343446 , 1.2937391 ], dtype=float32)),
#  ('DET',
#   array([0.46587753, 0.9663644 , 0.53256166, 0.5979579 , 0.82714266,
#          0.68895495, 0.92114055], dtype=float32)),
#  ('GSW',
#   array([1.6281062 , 1.3243853 , 0.86337245, 1.1841364 ], dtype=float32)),
#  ('HOU',
#   array([0.4027796 , 1.2593188 , 0.42809087, 1.3232727 , 1.1099995 ,
#          0.4765385 ], dtype=float32)),
#  ('IND',
#   array([0.6102214 , 0.7574965 , 0.46930814, 0.58234084, 0.62607175,
#          0.6357389 , 0.71546584, 0.6033565 ], dtype=float32)),
#  ('LAC', array([1.2346046, 1.3576729, 1.1271421, 1.2805809], dtype=float32)),
#  ('LAL',
#   array([1.3057042, 1.0095994, 1.2354959, 0.5558516, 0.8933486],
#         dtype=float32)),
#  ('MIA',
#   array([0.67789084, 0.99113333, 0.69400966, 0.68867755, 1.0569915 ,
#          0.89129746], dtype=float32)),
#  ('MIL',
#   array([0.83088624, 0.67059964, 0.81275487, 1.0640167 , 0.8697173 ,
#          0.7520251 ], dtype=float32)),
#  ('MIN',
#   array([0.8841449 , 0.8841478 , 0.7638547 , 0.8613891 , 0.85422873,
#          0.7522348 ], dtype=float32)),
#  ('NYK',
#   array([0.6817028 , 0.84895205, 0.66110086, 0.5777638 , 0.57242846,
#          0.6732844 , 0.3576072 , 0.62716067], dtype=float32)),
#  ('ORL',
#   array([0.70378476, 1.1848801 , 0.9010673 , 2.2102675 ], dtype=float32)),
#  ('PHI',
#   array([0.66251755, 0.7591007 , 0.800094  , 0.6696855 , 0.7254064 ,
#          0.7671821 , 0.6160135 ], dtype=float32)),
#  ('PHO',
#   array([1.2724913, 0.6928981, 1.1196885, 1.0500119, 0.8649101],
#         dtype=float32)),
#  ('POR',
#   array([0.3631357 , 0.45487064, 0.40980938, 0.8230227 , 0.38508055,
#          1.9781528 , 0.319021  , 0.26690727], dtype=float32)),
#  ('SAC',
#   array([0.6121996 , 0.5494699 , 0.74965835, 0.5363109 , 0.5423689 ,
#          0.5647943 , 0.46803832, 0.5249351 , 0.45222425], dtype=float32)),
#  ('SAS',
#   array([0.40626946, 0.447675  , 0.34663385, 0.42936343, 0.41076022,
#          0.49338427, 1.4769279 , 0.57750297, 0.41148293], dtype=float32)),
#  ('TOR',
#   array([0.5098303 , 0.67119306, 0.8168931 , 0.57224286, 0.5267106 ,
#          0.45376897, 0.43974635, 0.56413716, 0.44547763], dtype=float32)),
#  ('UTA',
#   array([0.30578363, 0.47484264, 0.45667088, 0.4198365 , 0.3951256 ,
#          2.182512  , 0.4075969 , 0.35763142], dtype=float32)),
#  ('WAS',
#   array([0.74064904, 1.8956517 , 0.72702533, 1.6366739 ], dtype=float32)),
#  ('CHH', array([2.0854883 , 0.61123794, 2.3032737 ], dtype=float32)),
#  ('NJN',
#   array([1.5045171 , 1.5114477 , 0.42116892, 1.562866  ], dtype=float32)),
#  ('SEA',
#   array([0.518852  , 1.0698483 , 0.77949476, 2.6318045 ], dtype=float32)),
#  ('VAN',
#   array([0.6179179 , 0.62899435, 0.7059414 , 0.90669805, 0.94113934,
#          0.66358024, 0.53572917], dtype=float32))]

# %%
r_baseline[2000]
# Out:
# [('ATL',
#   tensor([0.7626, 0.3545, 1.0201, 1.2466, 1.0840, 0.5323], dtype=torch.float64)),
#  ('BOS',
#   tensor([0.4290, 0.6601, 0.4160, 0.7450, 1.2914, 1.4586], dtype=torch.float64)),
#  ('CHI', tensor([1.3872, 1.9789, 1.6339], dtype=torch.float64)),
#  ('CLE',
#   tensor([0.5295, 0.4648, 0.3924, 1.1572, 0.9694, 0.5466, 0.9401],
#          dtype=torch.float64)),
#  ('DAL', tensor([1.1966, 0.5307, 1.9097, 1.3629], dtype=torch.float64)),
#  ('DEN', tensor([1.0139, 1.8661, 0.5551, 1.5649], dtype=torch.float64)),
#  ('DET',
#   tensor([0.2477, 0.2975, 1.2993, 0.8387, 0.1396, 1.0790, 1.0983],
#          dtype=torch.float64)),
#  ('GSW', tensor([1.5144, 0.6482, 1.3748, 1.4626], dtype=torch.float64)),
#  ('HOU',
#   tensor([1.0825, 0.4135, 0.7582, 0.9812, 0.9676, 0.7970], dtype=torch.float64)),
#  ('IND',
#   tensor([0.4938, 0.9699, 0.8375, 0.6504, 0.2866, 0.3921, 0.8148, 0.5549],
#          dtype=torch.float64)),
#  ('LAC', tensor([1.3293, 1.2244, 0.9141, 1.5322], dtype=torch.float64)),
#  ('LAL',
#   tensor([1.4370, 0.6282, 0.5161, 0.6914, 1.7273], dtype=torch.float64)),
#  ('MIA',
#   tensor([0.9283, 1.0257, 0.8043, 1.1196, 0.4411, 0.6809], dtype=torch.float64)),
#  ('MIL',
#   tensor([1.2862, 0.4988, 1.0127, 0.5559, 1.1916, 0.4548], dtype=torch.float64)),
#  ('MIN',
#   tensor([2.2252, 0.2860, 0.2338, 0.7015, 0.5531, 1.0002], dtype=torch.float64)),
#  ('NYK',
#   tensor([0.8723, 0.5324, 0.2565, 0.7960, 0.7472, 0.6922, 0.3060, 0.7973],
#          dtype=torch.float64)),
#  ('ORL', tensor([1.2503, 1.8157, 0.7300, 1.2040], dtype=torch.float64)),
#  ('PHI',
#   tensor([0.5614, 0.4985, 1.0193, 0.8583, 0.5448, 0.6866, 0.8312],
#          dtype=torch.float64)),
#  ('PHO',
#   tensor([1.0272, 1.0410, 1.3297, 0.8100, 0.7920], dtype=torch.float64)),
#  ('POR',
#   tensor([0.3819, 0.2878, 0.5522, 0.9464, 0.7344, 0.5257, 0.7360, 0.8354],
#          dtype=torch.float64)),
#  ('SAC',
#   tensor([0.5461, 0.4331, 0.3014, 0.7711, 0.2979, 0.4314, 1.0978, 0.7037, 0.4175],
#          dtype=torch.float64)),
#  ('SAS',
#   tensor([0.3415, 1.1390, 0.4473, 0.3255, 0.5960, 0.3650, 0.4623, 0.8976, 0.4259],
#          dtype=torch.float64)),
#  ('TOR',
#   tensor([0.9107, 0.7072, 0.2719, 0.6714, 0.7882, 0.6979, 0.1430, 0.3254, 0.4844],
#          dtype=torch.float64)),
#  ('UTA',
#   tensor([0.4950, 0.5249, 0.2244, 1.1227, 0.4599, 0.4901, 0.7687, 0.9143],
#          dtype=torch.float64)),
#  ('WAS', tensor([0.8224, 1.2728, 1.2343, 1.6705], dtype=torch.float64)),
#  ('CHH', tensor([1.2006, 1.0585, 2.7410], dtype=torch.float64)),
#  ('NJN', tensor([1.4220, 1.1857, 0.6281, 1.7641], dtype=torch.float64)),
#  ('SEA', tensor([0.3641, 1.5095, 0.7501, 2.3763], dtype=torch.float64)),
#  ('VAN',
#   tensor([1.1713, 1.0921, 0.7839, 0.7043, 0.6147, 0.2976, 0.3361],
#          dtype=torch.float64))]

# %%
# Min 00

sgd = [0.9151, 0.7806, 0.8028, 0.8257, 0.8211, 0.8547]
      [0.7422, 0.9261, 0.6482, 0.8753, 0.9312, 0.8769]
      [0.8841, 0.8841, 0.7639, 0.8614, 0.8542, 0.7522]
bl =  [2.2252, 0.2860, 0.2338, 0.7015, 0.5531, 1.0002]

# %% [markdown]
# Define SGD loss functions, $F^*$.
# Define ground truth loss function, $F$.
#
# $F^*\left(\mu^*,\{T\}|\nu,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),T^l>-\frac{1}{\lambda}H(T^l)-\frac{1}{\lambda_{\mu}}H(\mu^*) \right)$,
# where $H(T^l)=-\sum_{i,j}T^l_{i,j}(\text{ln}(T^l_{i,j})-1)$ and $H(\mu^*)=-\sum_{i}\mu_i(\text{ln}(\mu^*)-1)$ are the entropic regularizations. $\lambda$ and $\lambda_{\mu}$ are hyperparaters set to 1. $\mu^*$ is the resulted row marginal from performing SGD on $\{K^{(y,t)}\}$. $T^l=SK^L(\mu^*, \nu, K^l)$ is the $L$-step Sinkhorn approximation.
#
# $F\left(\mu^g,\tilde{T^g},\nu^g,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),\tilde{T^g}>-\frac{1}{\lambda}H(\tilde{T^g})-\frac{1}{\lambda_{\mu}}H(\mu) \right)$,
# where $\mu^g,\nu^g$, and, $\tilde{T^g}$ are the ground truth marginals and coupling.
#
# Define index $I = F^*/N-F/N$. $N$ is the sample size of $\{K\}$.
#
# Assume the PIOT inferred $\{K\}$ reflect the players' ability, EOT and SGD find a solution of the marginal, $\mu^*$, which minimizes the total loss $F^*$. Such $\mu^*$ is the marginal when the teammates cooperate in a best way. The figure shows the correlation between the win rate and $I$. We find that $F^* < F$ (Since $I<0$.) for all teams from 1991 to 2019 as shown in the figure.
#
# Try other definitions of $I$, $F^*$, and $F$, such as $I=\sum_l \frac{(F^{*,l}-F^{l})}{F^{l}}$ to see if there is any correlation to win rateor other empirical data.
