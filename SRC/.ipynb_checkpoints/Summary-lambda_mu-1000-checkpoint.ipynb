# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_sgd = {}
data_baseline = {}
for year in range(1991, 2020):
    y_str = str(year)
    with open('./data/loss_lam10_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_sgd:
                    data_sgd[year] = []
                team, loss = pickle.load(f)
                data_sgd[year].append((team, loss.item()))
        except EOFError:
            pass

    
    with open('./data/loss-baseline_lam10_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_baseline:
                    data_baseline[year] = []
                team, loss = pickle.load(f)
                data_baseline[year].append((team, loss))
        except EOFError:
            pass

# %%
def get_loss(data, name):
    loss = pd.DataFrame()
    for year in range(1991, 2020):
        if len(data[year]) != 0:
            if loss.empty:
                loss = pd.DataFrame.from_dict(data[year])
                loss.columns = ['Team', 'Loss_'+name]
                loss['Year'] = year
            else:
                tmp = pd.DataFrame.from_dict(data[year])
                tmp.columns = ['Team', 'Loss_'+name]
                tmp['Year'] = year        
                loss = pd.concat([loss, tmp])
    return loss

loss_sgd = get_loss(data_sgd, 'SGD')
loss_baseline = get_loss(data_baseline, 'baseline')

# %%
win_rate = pd.DataFrame()
cols = ['Team', 'W/L%']

for year in range(1991, 2020):
    y_str = str(year)

    path1 = '../NBA/data/win_rate/win_rate_W_{}.csv'.format(y_str)
    path2 = '../NBA/data/win_rate/win_rate_E_{}.csv'.format(y_str)

    
    win_rate1 = pd.read_csv(path1)[cols]
    win_rate2 = pd.read_csv(path2)[cols]
    tmp = pd.concat([win_rate1, win_rate2])
    tmp["Year"] = year
    if win_rate.empty:
        win_rate = tmp
    else:
        win_rate = pd.concat([win_rate, tmp])
win_rate = win_rate.merge(loss_sgd, on = ['Team', 'Year'], how = 'right')    
win_rate = win_rate.merge(loss_baseline, on = ['Team', 'Year'], how = 'left')
win_rate
# Out:
#     Team   W/L%  Year     Loss_SGD  Loss_baseline
# 0    ATL  0.524  1991 -607705.6875 -585631.864447
# 1    BOS  0.683  1991 -662041.4375 -591663.938634
# 2    CHI  0.744  1991 -857044.7500 -756619.807173
# 3    CLE  0.402  1991 -535907.3125 -485055.157620
# 4    DAL  0.341  1991 -671205.1250 -648483.216328
# ..   ...    ...   ...          ...            ...
# 805  SAC  0.476  2019 -670536.4375 -625371.857337
# 806  SAS  0.585  2019 -721781.3750 -671645.004983
# 807  TOR  0.707  2019 -660412.3125 -631728.191300
# 808  UTA  0.610  2019 -757300.8125 -696126.488489
# 809  WAS  0.390  2019 -419826.0625 -408032.484542
#
# [810 rows x 5 columns]

# %%
win_rate['I'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/10000)
win_rate['I_norm'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/np.abs(win_rate['Loss_baseline']))

# %%
win_rate.dropna().sort_values("I")[:20]
# Out:
#     Team   W/L%  Year     Loss_SGD  Loss_baseline          I    I_norm
# 262  MIN  0.610  2000 -600668.3125 -444346.154665 -15.632216 -0.351803
# 614  GSW  0.573  2013 -632961.1250 -505449.357004 -12.751177 -0.252274
# 307  BOS  0.598  2002 -621805.0000 -499588.114909 -12.221689 -0.244635
# 44   PHI  0.427  1992 -606295.8750 -484711.471424 -12.158440 -0.250839
# 254  DET  0.512  2000 -656353.7500 -534908.909555 -12.144484 -0.227038
# 514  MIA  0.524  2009 -545167.9375 -427035.239096 -11.813270 -0.276635
# 800  OKC  0.598  2019 -687420.1875 -569940.087385 -11.748010 -0.206127
# 29   CHI  0.817  1992 -838551.5000 -722009.173259 -11.654233 -0.161414
# 710  OKC  0.671  2016 -744899.5000 -629272.151325 -11.562735 -0.183748
# 527  NOH  0.598  2009 -844393.5000 -732848.293414 -11.154521 -0.152208
# 568  MIA  0.707  2011 -865959.2500 -754902.641402 -11.105661 -0.147114
# 406  MIN  0.537  2005 -695532.5625 -585014.996877 -11.051757 -0.188914
# 291  MIN  0.573  2001 -727590.5625 -617610.648646 -10.997991 -0.178073
# 164  CHI  0.841  1997 -934818.7500 -825665.729399 -10.915302 -0.132200
# 444  NJN  0.598  2006 -761339.0000 -653146.396581 -10.819260 -0.165648
# 770  OKC  0.585  2018 -685613.8750 -577646.492722 -10.796738 -0.186909
# 356  SAS  0.732  2003 -743206.8125 -637474.614690 -10.573220 -0.165861
# 725  CLE  0.622  2017 -743269.6875 -640010.450874 -10.325924 -0.161340
# 2    CHI  0.744  1991 -857044.7500 -756619.807173 -10.042494 -0.132728
# 645  LAC  0.695  2014 -739867.7500 -640111.649712  -9.975610 -0.155842

# %%
import seaborn as sns
x, y = win_rate['I'], win_rate['W/L%']
sns.kdeplot(x, y, fill=True, levels = 50, thresh=0, cmap = 'Blues')
sns.kdeplot(x, y, fill=False, levels = [0, 0.025, 1], thresh=0, cmap = 'autumn')
plt.show()
# Out:
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize = (10, 6))
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 10, c=win_rate['Year'], cmap='viridis')
sns.kdeplot(x, y, fill=False, levels = [0, 0.025, 1], thresh=0, cmap = 'autumn')
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
#fig.colorbar()
# Out:
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 8)
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
r_sgd = {}
r_baseline = {}
for year in range(1991, 2020):
    y_str = str(year)
    with open('./data/r_lam10_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in r_sgd:
                    r_sgd[year] = []
                team, r = pickle.load(f)
                r_sgd[year].append((team, r))
        except EOFError:
            pass

    
    with open('./data/r-baseline_lam10_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in r_baseline:
                    r_baseline[year] = []
                team, r = pickle.load(f)
                r_baseline[year].append((team, r))
        except EOFError:
            pass

# %%
r_sgd[2000]
# Out:
# [('ATL',
#   array([0.85497147, 0.8663124 , 0.7991755 , 0.84477574, 0.77659696,
#          0.85816795], dtype=float32)),
#  ('BOS',
#   array([0.8058026 , 0.7956204 , 0.85588455, 0.86188465, 0.85390323,
#          0.8269044 ], dtype=float32)),
#  ('CHI', array([2.6719007, 1.1993103, 1.1287893], dtype=float32)),
#  ('CLE',
#   array([0.72639894, 0.7145858 , 0.7237339 , 0.72096163, 0.69585496,
#          0.71318996, 0.70527434], dtype=float32)),
#  ('DAL', array([1.2344675, 1.2520299, 1.2332451, 1.2802579], dtype=float32)),
#  ('DEN', array([1.208257 , 1.3717058, 1.205888 , 1.2141491], dtype=float32)),
#  ('DET',
#   array([0.69268876, 0.7288034 , 0.72808677, 0.6724364 , 0.74881697,
#          0.72035545, 0.70881224], dtype=float32)),
#  ('GSW', array([1.3030097, 1.2205656, 1.2832408, 1.1931841], dtype=float32)),
#  ('HOU',
#   array([0.78805596, 0.8676367 , 0.8383188 , 0.863791  , 0.8660188 ,
#          0.7761791 ], dtype=float32)),
#  ('IND',
#   array([0.6602615 , 0.62673616, 0.6121529 , 0.60877794, 0.6312278 ,
#          0.62511516, 0.62225336, 0.6134749 ], dtype=float32)),
#  ('LAC', array([1.2910545, 1.2502573, 1.2543926, 1.2042956], dtype=float32)),
#  ('LAL',
#   array([0.9870437 , 0.96570426, 1.0672166 , 0.9358642 , 1.044171  ],
#         dtype=float32)),
#  ('MIA',
#   array([0.81378746, 0.85205126, 0.85874265, 0.81336623, 0.8731363 ,
#          0.7889158 ], dtype=float32)),
#  ('MIL',
#   array([0.8537609 , 0.8250037 , 0.83190215, 0.8438665 , 0.8247215 ,
#          0.8207452 ], dtype=float32)),
#  ('MIN',
#   array([0.8250749 , 0.84388566, 0.82660127, 0.8074862 , 0.8554233 ,
#          0.8415287 ], dtype=float32)),
#  ('NYK',
#   array([0.6161977 , 0.6353113 , 0.63057786, 0.63616765, 0.61694777,
#          0.6443877 , 0.57279104, 0.6476188 ], dtype=float32)),
#  ('ORL', array([1.2001809, 1.2579439, 1.259131 , 1.2827443], dtype=float32)),
#  ('PHI',
#   array([0.72274154, 0.72019166, 0.71146494, 0.72100466, 0.7088581 ,
#          0.71032166, 0.7054174 ], dtype=float32)),
#  ('PHO',
#   array([0.99886966, 0.9770014 , 1.004281  , 1.0163502 , 1.003498  ],
#         dtype=float32)),
#  ('POR',
#   array([0.6491118 , 0.593941  , 0.60446906, 0.6659101 , 0.62318194,
#          0.6781883 , 0.599357  , 0.5858406 ], dtype=float32)),
#  ('SAC',
#   array([0.5677312 , 0.5396123 , 0.5789568 , 0.56011117, 0.5422485 ,
#          0.5281593 , 0.5588833 , 0.5570637 , 0.5672342 ], dtype=float32)),
#  ('SAS',
#   array([0.5442119 , 0.5388857 , 0.55140084, 0.5392491 , 0.5615718 ,
#          0.57254267, 0.5809454 , 0.55414045, 0.55705184], dtype=float32)),
#  ('TOR',
#   array([0.54515296, 0.5433976 , 0.5823897 , 0.5621497 , 0.5510867 ,
#          0.5604147 , 0.5507662 , 0.53729296, 0.56734943], dtype=float32)),
#  ('UTA',
#   array([0.6466171 , 0.62290365, 0.6409472 , 0.5727231 , 0.6519074 ,
#          0.6960325 , 0.5780424 , 0.59082675], dtype=float32)),
#  ('WAS', array([1.1940093, 1.2952007, 1.2221352, 1.2886546], dtype=float32)),
#  ('CHH', array([1.3043103, 2.4425607, 1.253129 ], dtype=float32)),
#  ('NJN', array([1.1591269, 1.675344 , 1.0593063, 1.1062231], dtype=float32)),
#  ('SEA', array([1.1800759, 1.2651842, 1.2111081, 1.3436317], dtype=float32)),
#  ('VAN',
#   array([0.70342386, 0.7366054 , 0.7141434 , 0.7114888 , 0.7366442 ,
#          0.68050236, 0.7171924 ], dtype=float32))]

# %%
r_baseline[2000]
# Out:
# [('ATL',
#   tensor([0.7626, 0.3545, 1.0201, 1.2466, 1.0840, 0.5323], dtype=torch.float64)),
#  ('BOS',
#   tensor([0.4290, 0.6601, 0.4160, 0.7450, 1.2914, 1.4586], dtype=torch.float64)),
#  ('CHI', tensor([1.3872, 1.9789, 1.6339], dtype=torch.float64)),
#  ('CLE',
#   tensor([0.5295, 0.4648, 0.3924, 1.1572, 0.9694, 0.5466, 0.9401],
#          dtype=torch.float64)),
#  ('DAL', tensor([1.1966, 0.5307, 1.9097, 1.3629], dtype=torch.float64)),
#  ('DEN', tensor([1.0139, 1.8661, 0.5551, 1.5649], dtype=torch.float64)),
#  ('DET',
#   tensor([0.2477, 0.2975, 1.2993, 0.8387, 0.1396, 1.0790, 1.0983],
#          dtype=torch.float64)),
#  ('GSW', tensor([1.5144, 0.6482, 1.3748, 1.4626], dtype=torch.float64)),
#  ('HOU',
#   tensor([1.0825, 0.4135, 0.7582, 0.9812, 0.9676, 0.7970], dtype=torch.float64)),
#  ('IND',
#   tensor([0.4938, 0.9699, 0.8375, 0.6504, 0.2866, 0.3921, 0.8148, 0.5549],
#          dtype=torch.float64)),
#  ('LAC', tensor([1.3293, 1.2244, 0.9141, 1.5322], dtype=torch.float64)),
#  ('LAL',
#   tensor([1.4370, 0.6282, 0.5161, 0.6914, 1.7273], dtype=torch.float64)),
#  ('MIA',
#   tensor([0.9283, 1.0257, 0.8043, 1.1196, 0.4411, 0.6809], dtype=torch.float64)),
#  ('MIL',
#   tensor([1.2862, 0.4988, 1.0127, 0.5559, 1.1916, 0.4548], dtype=torch.float64)),
#  ('MIN',
#   tensor([2.2252, 0.2860, 0.2338, 0.7015, 0.5531, 1.0002], dtype=torch.float64)),
#  ('NYK',
#   tensor([0.8723, 0.5324, 0.2565, 0.7960, 0.7472, 0.6922, 0.3060, 0.7973],
#          dtype=torch.float64)),
#  ('ORL', tensor([1.2503, 1.8157, 0.7300, 1.2040], dtype=torch.float64)),
#  ('PHI',
#   tensor([0.5614, 0.4985, 1.0193, 0.8583, 0.5448, 0.6866, 0.8312],
#          dtype=torch.float64)),
#  ('PHO',
#   tensor([1.0272, 1.0410, 1.3297, 0.8100, 0.7920], dtype=torch.float64)),
#  ('POR',
#   tensor([0.3819, 0.2878, 0.5522, 0.9464, 0.7344, 0.5257, 0.7360, 0.8354],
#          dtype=torch.float64)),
#  ('SAC',
#   tensor([0.5461, 0.4331, 0.3014, 0.7711, 0.2979, 0.4314, 1.0978, 0.7037, 0.4175],
#          dtype=torch.float64)),
#  ('SAS',
#   tensor([0.3415, 1.1390, 0.4473, 0.3255, 0.5960, 0.3650, 0.4623, 0.8976, 0.4259],
#          dtype=torch.float64)),
#  ('TOR',
#   tensor([0.9107, 0.7072, 0.2719, 0.6714, 0.7882, 0.6979, 0.1430, 0.3254, 0.4844],
#          dtype=torch.float64)),
#  ('UTA',
#   tensor([0.4950, 0.5249, 0.2244, 1.1227, 0.4599, 0.4901, 0.7687, 0.9143],
#          dtype=torch.float64)),
#  ('WAS', tensor([0.8224, 1.2728, 1.2343, 1.6705], dtype=torch.float64)),
#  ('CHH', tensor([1.2006, 1.0585, 2.7410], dtype=torch.float64)),
#  ('NJN', tensor([1.4220, 1.1857, 0.6281, 1.7641], dtype=torch.float64)),
#  ('SEA', tensor([0.3641, 1.5095, 0.7501, 2.3763], dtype=torch.float64)),
#  ('VAN',
#   tensor([1.1713, 1.0921, 0.7839, 0.7043, 0.6147, 0.2976, 0.3361],
#          dtype=torch.float64))]

# %%
# Min 00

sgd = [0.9151, 0.7806, 0.8028, 0.8257, 0.8211, 0.8547] 1
      [0.7422, 0.9261, 0.6482, 0.8753, 0.9312, 0.8769] 10
      [0.8841, 0.8841, 0.7639, 0.8614, 0.8542, 0.7522] 100
      [0.8251, 0.8439, 0.8267, 0.8075, 0.8554, 0.8415] 0.1
bl =  [2.2252, 0.2860, 0.2338, 0.7015, 0.5531, 1.0002] mu^g
# Out:
#   File "<ipython-input-12-3ad034811a6e>", line 4
#     [0.7422, 0.9261, 0.6482, 0.8753, 0.9312, 0.8769]
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# Define SGD loss functions, $F^*$.
# Define ground truth loss function, $F$.
#
# $F^*\left(\mu^*,\{T\}|\nu,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),T^l>-\frac{1}{\lambda}H(T^l)-\frac{1}{\lambda_{\mu}}H(\mu^*) \right)$,
# where $H(T^l)=-\sum_{i,j}T^l_{i,j}(\text{ln}(T^l_{i,j})-1)$ and $H(\mu^*)=-\sum_{i}\mu_i(\text{ln}(\mu^*)-1)$ are the entropic regularizations. $\lambda$ and $\lambda_{\mu}$ are hyperparaters set to 1. $\mu^*$ is the resulted row marginal from performing SGD on $\{K^{(y,t)}\}$. $T^l=SK^L(\mu^*, \nu, K^l)$ is the $L$-step Sinkhorn approximation.
#
# $F\left(\mu^g,\tilde{T^g},\nu^g,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),\tilde{T^g}>-\frac{1}{\lambda}H(\tilde{T^g})-\frac{1}{\lambda_{\mu}}H(\mu) \right)$,
# where $\mu^g,\nu^g$, and, $\tilde{T^g}$ are the ground truth marginals and coupling.
#
# Define index $I = F^*/N-F/N$. $N$ is the sample size of $\{K\}$.
#
# Assume the PIOT inferred $\{K\}$ reflect the players' ability, EOT and SGD find a solution of the marginal, $\mu^*$, which minimizes the total loss $F^*$. Such $\mu^*$ is the marginal when the teammates cooperate in a best way. The figure shows the correlation between the win rate and $I$. We find that $F^* < F$ (Since $I<0$.) for all teams from 1991 to 2019 as shown in the figure.
#
# Try other definitions of $I$, $F^*$, and $F$, such as $I=\sum_l \frac{(F^{*,l}-F^{l})}{F^{l}}$ to see if there is any correlation to win rateor other empirical data.
