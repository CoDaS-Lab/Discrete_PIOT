# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_sgd = {}
data_baseline = {}
for year in range(1991, 2020):
    y_str = str(year)
    with open('./loss_lam0p1_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_sgd:
                    data_sgd[year] = []
                team, loss = pickle.load(f)
                data_sgd[year].append((team, loss.item()))
        except EOFError:
            pass

    
    with open('loss-baseline_lam0p1_{}.pkl'.format(y_str), 'rb') as f:
        try:
            while True:
                if year not in data_baseline:
                    data_baseline[year] = []
                team, loss = pickle.load(f)
                data_baseline[year].append((team, loss))
        except EOFError:
            pass

# %%
def get_loss(data, name):
    loss = pd.DataFrame()
    for year in range(1991, 2020):
        if len(data[year]) != 0:
            if loss.empty:
                loss = pd.DataFrame.from_dict(data[year])
                loss.columns = ['Team', 'Loss_'+name]
                loss['Year'] = year
            else:
                tmp = pd.DataFrame.from_dict(data[year])
                tmp.columns = ['Team', 'Loss_'+name]
                tmp['Year'] = year        
                loss = pd.concat([loss, tmp])
    return loss

loss_sgd = get_loss(data_sgd, 'SGD')
loss_baseline = get_loss(data_baseline, 'baseline')

# %%
win_rate = pd.DataFrame()
cols = ['Team', 'W/L%']

for year in range(1991, 2020):
    y_str = str(year)

    path1 = '../NBA/data/win_rate/win_rate_W_{}.csv'.format(y_str)
    path2 = '../NBA/data/win_rate/win_rate_E_{}.csv'.format(y_str)

    
    win_rate1 = pd.read_csv(path1)[cols]
    win_rate2 = pd.read_csv(path2)[cols]
    tmp = pd.concat([win_rate1, win_rate2])
    tmp["Year"] = year
    if win_rate.empty:
        win_rate = tmp
    else:
        win_rate = pd.concat([win_rate, tmp])
win_rate = win_rate.merge(loss_sgd, on = ['Team', 'Year'], how = 'right')    
win_rate = win_rate.merge(loss_baseline, on = ['Team', 'Year'], how = 'left')
win_rate
# Out:
#     Team   W/L%  Year      Loss_SGD  Loss_baseline
# 0    ATL  0.524  1991  -5414.088867   -1478.701309
# 1    BOS  0.683  1991  -1210.989136   11610.141755
# 2    CHI  0.744  1991 -51369.312500  -31461.709277
# 3    CLE  0.402  1991  -2669.481445    6268.355995
# 4    DAL  0.341  1991 -12727.226562   -7658.417889
# ..   ...    ...   ...           ...            ...
# 805  SAC  0.476  2019  -9593.099609    2363.704917
# 806  SAS  0.585  2019  -8498.588867    3765.630501
# 807  TOR  0.707  2019   2262.010254    5730.881694
# 808  UTA  0.610  2019 -41705.152344  -31291.167811
# 809  WAS  0.390  2019  27985.611328   33065.275805
#
# [810 rows x 5 columns]

# %%
win_rate['I'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/10000)
win_rate['I_norm'] = ((win_rate['Loss_SGD'] - win_rate['Loss_baseline'])/np.abs(win_rate['Loss_baseline']))

# %%
win_rate[win_rate['Team']=="LAL"]
# Out:
#     Team   W/L%  Year      Loss_SGD  Loss_baseline         I    I_norm
# 11   LAL  0.707  1991 -55929.847656  -42695.213521 -1.323463 -0.309979
# 38   LAL  0.524  1992 -47556.398438  -30448.120522 -1.710828 -0.561883
# 65   LAL  0.476  1993 -35203.312500  -27052.947472 -0.815037 -0.301275
# 92   LAL  0.402  1994   1232.002319   14839.910054 -1.360791 -0.916980
# 119  LAL  0.585  1995 -19039.019531  -12077.760157 -0.696126 -0.576370
# 146  LAL  0.646  1996 -25901.089844  -14808.031384 -1.109306 -0.749124
# 173  LAL  0.683  1997 -34268.820312  -20595.355848 -1.367346 -0.663910
# 202  LAL  0.744  1998 -49466.066406            NaN       NaN       NaN
# 230  LAL  0.620  1999  46552.203125   57393.276359 -1.084107 -0.188891
# 259  LAL  0.817  2000 -61887.187500  -50084.190170 -1.180300 -0.235663
# 288  LAL  0.683  2001 -31022.503906  -10517.137158 -2.050537 -1.949710
# 317  LAL  0.707  2002 -22350.265625   -6145.095501 -1.620517 -2.637090
# 345  LAL  0.610  2003 -24288.988281   -8305.780302 -1.598321 -1.924348
# 373  LAL  0.683  2004 -31037.916016  -16740.553732 -1.429736 -0.854056
# 402  LAL  0.415  2005 -39479.523438  -24394.987023 -1.508454 -0.618346
# 431  LAL  0.549  2006  14897.958008   26738.794757 -1.184084 -0.442834
# 457  LAL  0.512  2007 -56184.773438  -44414.972630 -1.176980 -0.264996
# 485  LAL  0.695  2008  -3477.742432    6904.607973 -1.038235 -1.503684
# 512  LAL  0.793  2009 -63679.000000  -52729.844916 -1.094916 -0.207646
# 539  LAL  0.695  2010 -33535.593750  -18533.567094 -1.500203 -0.809452
# 566  LAL  0.695  2011 -32488.300781  -22991.856165 -0.949644 -0.413035
# 592  LAL  0.621  2012 -12980.579102   -6991.272562 -0.598931 -0.856683
# 617  LAL  0.549  2013 -69214.171875  -58178.737507 -1.103543 -0.189682
# 646  LAL  0.329  2014  17027.099609   22624.675428 -0.559758 -0.247410
# 673  LAL  0.256  2015 -40931.269531  -35721.279039 -0.520999 -0.145851
# 703  LAL  0.207  2016  26795.662109   34473.297249 -0.767764 -0.222713
# 733  LAL  0.317  2017 -41890.628906  -37732.612058 -0.415802 -0.110197
# 763  LAL  0.427  2018 -13843.503906   -5999.722199 -0.784378 -1.307357
# 793  LAL  0.451  2019 -35237.527344  -24823.636632 -1.041389 -0.419515

# %%
win_rate.dropna().sort_values("I")[-50:]
# Out:
#     Team   W/L%  Year      Loss_SGD  Loss_baseline         I    I_norm
# 503  CHI  0.500  2009 -18548.128906  -15216.538307 -0.333159 -0.218945
# 664  BRK  0.463  2015  -1553.231567    1767.527454 -0.332076 -1.878760
# 387  WAS  0.305  2004  -7223.968262   -3915.098172 -0.330887 -0.845156
# 34   GSW  0.671  1992  36092.937500   39389.501278 -0.329656 -0.083691
# 474  SEA  0.378  2007 -22090.656250  -18802.810447 -0.328785 -0.174859
# 272  WAS  0.354  2000 -24784.677734  -21533.562883 -0.325111 -0.150979
# 228  IND  0.660  1999 -46130.777344  -42891.764424 -0.323901 -0.075516
# 200  IND  0.707  1998 -35162.312500  -31962.327723 -0.319998 -0.100117
# 536  HOU  0.512  2010 -18063.554688  -14885.326770 -0.317823 -0.213514
# 460  MIL  0.341  2007  10975.626953   14142.909392 -0.316728 -0.223948
# 587  DEN  0.576  2012   3263.926514    6332.633164 -0.306871 -0.484586
# 654  PHI  0.232  2014  36419.625000   39440.172102 -0.302055 -0.076586
# 635  BOS  0.305  2014 -20274.867188  -17288.633705 -0.298623 -0.172728
# 521  SAC  0.207  2009 -45920.906250  -42982.490158 -0.293842 -0.068363
# 679  NYK  0.207  2015  19752.675781   22646.453131 -0.289378 -0.127781
# 626  PHO  0.305  2013 -49909.855469  -47019.167817 -0.289069 -0.061479
# 266  PHO  0.646  2000 -41053.863281  -38185.814183 -0.286805 -0.075108
# 213  TOR  0.195  1998 -13199.484375  -10334.691807 -0.286479 -0.277202
# 713  PHO  0.280  2016 -14878.703125  -12060.547529 -0.281816 -0.233667
# 481  DET  0.720  2008  12592.821289   15402.102327 -0.280928 -0.182396
# 561  DET  0.366  2011 -12104.180664   -9324.727128 -0.277945 -0.298073
# 530  CHI  0.500  2010 -12928.663086  -10185.207603 -0.274346 -0.269357
# 486  MEM  0.268  2008  53806.417969   56493.129602 -0.268671 -0.047558
# 400  IND  0.537  2005 -21401.384766  -18722.161978 -0.267922 -0.143104
# 500  SEA  0.244  2008 -23612.660156  -20946.841105 -0.266582 -0.127266
# 69   NYK  0.732  1993 -61732.078125  -59082.370051 -0.264971 -0.044848
# 313  GSW  0.256  2002  14366.510742   17000.496861 -0.263399 -0.154936
# 734  MEM  0.524  2017 -14935.415039  -12322.566547 -0.261285 -0.212038
# 31   DAL  0.268  1992 -20788.167969  -18175.700067 -0.261247 -0.143734
# 627  POR  0.402  2013  48717.347656   51270.534987 -0.255319 -0.049798
# 82   BOS  0.390  1994  -3702.574219   -1198.775147 -0.250380 -2.088631
# 756  DAL  0.293  2018  -4171.176758   -1675.635637 -0.249554 -1.489310
# 562  GSW  0.439  2011  -4564.410156   -2078.377092 -0.248603 -1.196141
# 350  NYK  0.451  2003 -46130.562500  -43714.111775 -0.241645 -0.055279
# 274  NJN  0.378  2000 -72276.523438  -69865.297735 -0.241123 -0.034512
# 598  PHI  0.530  2012 -18209.882812  -15947.956709 -0.226193 -0.141832
# 506  DEN  0.659  2009 -29921.955078  -27813.420067 -0.210854 -0.075810
# 250  CHI  0.207  2000   -487.821106    1528.530397 -0.201635 -1.319144
# 467  SAC  0.402  2007 -46025.566406  -44021.927644 -0.200364 -0.045515
# 211  SAC  0.329  1998  29538.878906   31531.651525 -0.199277 -0.063199
# 346  MEM  0.341  2003 -30263.289062  -28351.316902 -0.191197 -0.067439
# 20   SAC  0.305  1991  86938.140625   88849.284937 -0.191114 -0.021510
# 229  LAC  0.180  1999  30315.914062   32175.131246 -0.185922 -0.057784
# 58   DAL  0.134  1993  10792.709961   12084.110069 -0.129140 -0.106868
# 403  MEM  0.549  2005 -56419.468750  -55400.937121 -0.101853 -0.018385
# 540  MEM  0.488  2010  52628.046875   53522.319925 -0.089427 -0.016708
# 86   DEN  0.512  1994  28992.732422   29828.710170 -0.083598 -0.028026
# 707  MIN  0.354  2016  33050.066406   33779.976143 -0.072991 -0.021608
# 357  TOR  0.293  2003 -16900.638672  -17032.263454  0.013162  0.007728
# 245  NJN  0.320  1999  65238.363281   64697.123903  0.054124  0.008366

# %%
import seaborn as sns
x, y = win_rate['I'], win_rate['W/L%']
sns.kdeplot(x, y, fill=True, levels = 50, thresh=0, cmap = 'Blues')
plt.show()
# Out:
# /Users/Will/anaconda/envs/pyOT/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 18})

fig = plt.figure(figsize = (10, 6))
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 10, c=win_rate['Year'], cmap='viridis')
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
#fig.colorbar()
# Out:
# (0.0, 1.0)

# %%
fig = plt.figure()
ax = plt.subplot(111)
win_rate.plot.scatter(x='I',y='W/L%',ax=ax, s = 8)
#ax.set_xlim(-2.5,0)
ax.set_ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# Define SGD loss functions, $F^*$.
# Define ground truth loss function, $F$.
#
# $F^*\left(\mu^*,\{T\}|\nu,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),T^l>-\frac{1}{\lambda}H(T^l)-\frac{1}{\lambda_{\mu}}H(\mu^*) \right)$,
# where $H(T^l)=-\sum_{i,j}T^l_{i,j}(\text{ln}(T^l_{i,j})-1)$ and $H(\mu^*)=-\sum_{i}\mu_i(\text{ln}(\mu^*)-1)$ are the entropic regularizations. $\lambda$ and $\lambda_{\mu}$ are hyperparaters set to 1. $\mu^*$ is the resulted row marginal from performing SGD on $\{K^{(y,t)}\}$. $T^l=SK^L(\mu^*, \nu, K^l)$ is the $L$-step Sinkhorn approximation.
#
# $F\left(\mu^g,\tilde{T^g},\nu^g,\{K\}\right)=\left( \sum_l<-\text{ln}(K^{l}),\tilde{T^g}>-\frac{1}{\lambda}H(\tilde{T^g})-\frac{1}{\lambda_{\mu}}H(\mu) \right)$,
# where $\mu^g,\nu^g$, and, $\tilde{T^g}$ are the ground truth marginals and coupling.
#
# Define index $I = F^*/N-F/N$. $N$ is the sample size of $\{K\}$.
#
# Assume the PIOT inferred $\{K\}$ reflect the players' ability, EOT and SGD find a solution of the marginal, $\mu^*$, which minimizes the total loss $F^*$. Such $\mu^*$ is the marginal when the teammates cooperate in a best way. The figure shows the correlation between the win rate and $I$. We find that $F^* < F$ (Since $I<0$.) for all teams from 1991 to 2019 as shown in the figure.
#
# Try other definitions of $I$, $F^*$, and $F$, such as $I=\sum_l \frac{(F^{*,l}-F^{l})}{F^{l}}$ to see if there is any correlation to win rateor other empirical data.
