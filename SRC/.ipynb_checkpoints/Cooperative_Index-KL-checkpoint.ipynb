# %%
import sys
import os
sys.path.append('../SRC')
from PIOT_imports import *
import pickle
from tqdm import tqdm
from torch.distributions import Dirichlet
from numpy.random import uniform
import random

# %%
from PIOT_PSGD import *

def get_team_data_exclude_none(year, team1, load_folder = '../NBA/data/team_data/'):
    
    player_transfer_path = '../NBA/data/player_transfer/player_transfer_all_years.pkl'
    with open(player_transfer_path, 'rb') as f:
        player_transfer = pickle.load(f)
        
    y_str_minus_1 = str(year-1)
    y_str = str(year)
    team_composite = [team1]

    pre_team = find_pre_team(player_transfer, year, team1)

    with open(load_folder + '{}_{}.pkl'.format(team1, y_str), 'rb') as f:
        data_cur_season = pickle.load(f).reset_index()

    data_pre_season = {}
    with open(load_folder + '{}_{}.pkl'.format(team1, y_str_minus_1), 'rb') as f:
        data_pre_season[team1] = pickle.load(f).reset_index()

    for p, t in pre_team:
        team_composite.append(t)
        with open(load_folder + '{}_{}.pkl'.format(t, y_str_minus_1), 'rb') as f:
            data_tmp = pickle.load(f).reset_index()
        data_pre_season[t] = data_tmp

    players_cur = pd.DataFrame(data_cur_season["Player"])
    players_pre = pd.DataFrame(data_pre_season[team1]["Player"])

    for t in team_composite:
        players_cur[t] = find_index(players_cur, data_pre_season[t])

    idx_cost_mat = []
    marginal_exclusion = []
    for idx in range(len(players_cur)):
        tf = False
        for t in team_composite:
            if players_cur.iloc[idx][t] != -1:
                tf = True
                break
        if tf:
            idx_cost_mat.append((idx, t, players_cur.iloc[idx][t])) 
        else:
            marginal_exclusion.append(idx)
            
    cols = ['PTS','ORB','DRB','AST','STL']

    # Get ground truth T
    
    T_truth = data_cur_season[cols].drop(index = marginal_exclusion)
    T_truth = T_truth / T_truth.sum(axis=0)
    T_truth = data_to_mat(T_truth)

    return T_truth

def get_team_data(year, team1, load_folder = '../NBA/data/team_data/'):
    
    y_str = str(year)
    with open(load_folder + '{}_{}.pkl'.format(team1, y_str), 'rb') as f:
        data_cur_season = pickle.load(f).reset_index()

            
    cols = ['PTS','ORB','DRB','AST','STL']

    # Get ground truth T
    
    T_truth = data_cur_season[cols]
    T_truth = T_truth / T_truth.sum(axis=0)
    T_truth = data_to_mat(T_truth)

    return T_truth

def get_K_matrices(year, team):
    pkl_file = open('../NBA/data_K/{}/{}/K_{}_{}.pkl'.format(str(year), team, str(year), team), 'rb')
    return pickle.load(pkl_file)

# %%
team_list = get_team_list()
year = 2019
data = {}

for team in team_list:
    try:
        T = get_team_data(2019, team)
        data[team] = T
    except:
        pass

# %%
data
# Out:
# {'ATL': tensor([[0.0282, 0.0373, 0.0331, 0.0175, 0.0515],
#          [0.0883, 0.0448, 0.0840, 0.0807, 0.1340],
#          [0.0639, 0.0522, 0.0941, 0.0877, 0.1340],
#          [0.0563, 0.0299, 0.0534, 0.0386, 0.0619],
#          [0.1484, 0.2687, 0.1578, 0.0702, 0.0412],
#          [0.0822, 0.1194, 0.1501, 0.0491, 0.1134],
#          [0.0738, 0.0597, 0.0636, 0.1018, 0.0928],
#          [0.0845, 0.1567, 0.0891, 0.0386, 0.0412],
#          [0.0814, 0.0224, 0.0509, 0.1228, 0.0722],
#          [0.1027, 0.0299, 0.0814, 0.0737, 0.1031],
#          [0.0449, 0.1194, 0.0687, 0.0351, 0.0619],
#          [0.1454, 0.0597, 0.0738, 0.2842, 0.0928]], dtype=torch.float64),
#  'BOS': tensor([[0.0443, 0.1478, 0.0769, 0.0375, 0.0211],
#          [0.1029, 0.0783, 0.0872, 0.0478, 0.0947],
#          [0.0911, 0.0609, 0.0974, 0.1160, 0.0947],
#          [0.1077, 0.1565, 0.1282, 0.1433, 0.0947],
#          [0.1884, 0.0957, 0.1000, 0.2355, 0.1579],
#          [0.1101, 0.0870, 0.1308, 0.0512, 0.0632],
#          [0.0261, 0.0348, 0.0282, 0.0137, 0.0211],
#          [0.0713, 0.0348, 0.0897, 0.0990, 0.0947],
#          [0.0705, 0.0609, 0.0564, 0.1365, 0.1895],
#          [0.1243, 0.0783, 0.1333, 0.0717, 0.1158],
#          [0.0451, 0.1130, 0.0538, 0.0341, 0.0316],
#          [0.0182, 0.0522, 0.0179, 0.0137, 0.0211]], dtype=torch.float64),
#  'BRK': tensor([[0.0903, 0.2087, 0.1579, 0.0560, 0.0725],
#          [0.0920, 0.0870, 0.1105, 0.0520, 0.0725],
#          [0.0795, 0.0348, 0.0816, 0.0440, 0.0725],
#          [0.0481, 0.2348, 0.1553, 0.0320, 0.0580],
#          [0.1392, 0.0348, 0.0553, 0.1840, 0.0870],
#          [0.0406, 0.0522, 0.0553, 0.0560, 0.0870],
#          [0.1135, 0.0609, 0.0816, 0.0960, 0.0725],
#          [0.0737, 0.1217, 0.1000, 0.0640, 0.1014],
#          [0.0704, 0.0783, 0.0789, 0.0320, 0.1014],
#          [0.0779, 0.0261, 0.0395, 0.1040, 0.1014],
#          [0.1748, 0.0609, 0.0842, 0.2800, 0.1739]], dtype=torch.float64),
#  'CHI': tensor([[0.0603, 0.0309, 0.0640, 0.1381, 0.1096],
#          [0.0656, 0.0103, 0.0453, 0.0293, 0.0274],
#          [0.0926, 0.2062, 0.1333, 0.0753, 0.0822],
#          [0.1016, 0.0412, 0.0987, 0.2510, 0.2055],
#          [0.0360, 0.1340, 0.0613, 0.0251, 0.0274],
#          [0.0585, 0.0515, 0.0693, 0.0795, 0.1644],
#          [0.0468, 0.0722, 0.0933, 0.0335, 0.0685],
#          [0.2131, 0.0619, 0.1067, 0.1883, 0.1370],
#          [0.0854, 0.1959, 0.0533, 0.0502, 0.0137],
#          [0.1682, 0.1443, 0.2027, 0.0586, 0.0959],
#          [0.0719, 0.0515, 0.0720, 0.0711, 0.0685]], dtype=torch.float64),
#  'CHO': tensor([[0.0540, 0.0155, 0.0447, 0.0382, 0.0349],
#          [0.0687, 0.0698, 0.1012, 0.1146, 0.1047],
#          [0.0325, 0.1163, 0.0729, 0.0208, 0.0233],
#          [0.0554, 0.0620, 0.0753, 0.0417, 0.0814],
#          [0.0347, 0.0155, 0.0282, 0.0903, 0.0581],
#          [0.0540, 0.1550, 0.0776, 0.0347, 0.0349],
#          [0.0636, 0.0620, 0.0612, 0.0451, 0.0349],
#          [0.0495, 0.1085, 0.0588, 0.0347, 0.0581],
#          [0.1131, 0.0620, 0.1106, 0.0764, 0.1279],
#          [0.0658, 0.0155, 0.0400, 0.0556, 0.0581],
#          [0.0702, 0.0233, 0.0282, 0.1285, 0.0465],
#          [0.1892, 0.0465, 0.0894, 0.2049, 0.1395],
#          [0.0746, 0.0775, 0.1035, 0.0417, 0.1047],
#          [0.0746, 0.1705, 0.1082, 0.0729, 0.0930]], dtype=torch.float64),
#  'CLE': tensor([[0.1801, 0.0847, 0.0804, 0.1395, 0.1186],
#          [0.1308, 0.0339, 0.0734, 0.1163, 0.1356],
#          [0.1008, 0.2119, 0.1993, 0.1860, 0.2542],
#          [0.0697, 0.0678, 0.0839, 0.0640, 0.1186],
#          [0.1393, 0.0508, 0.1434, 0.1512, 0.1356],
#          [0.1790, 0.0593, 0.0769, 0.1744, 0.0847],
#          [0.1168, 0.3390, 0.2168, 0.1163, 0.1186],
#          [0.0836, 0.1525, 0.1259, 0.0523, 0.0339]], dtype=torch.float64),
#  'DAL': tensor([[0.1542, 0.0625, 0.0868, 0.0605, 0.1061],
#          [0.0348, 0.0179, 0.0323, 0.0233, 0.0152],
#          [0.0810, 0.0268, 0.0496, 0.1488, 0.0758],
#          [0.1847, 0.1071, 0.1638, 0.2791, 0.1667],
#          [0.0653, 0.1518, 0.0769, 0.0558, 0.1364],
#          [0.0549, 0.0179, 0.0372, 0.0837, 0.0758],
#          [0.0958, 0.2857, 0.2605, 0.0930, 0.1061],
#          [0.0592, 0.1161, 0.0844, 0.0465, 0.0758],
#          [0.1141, 0.0446, 0.0471, 0.1070, 0.1212],
#          [0.0636, 0.0089, 0.0744, 0.0326, 0.0303],
#          [0.0923, 0.1607, 0.0868, 0.0698, 0.0909]], dtype=torch.float64),
#  'DEN': tensor([[0.0921, 0.0538, 0.0997, 0.0960, 0.0460],
#          [0.0905, 0.0308, 0.0512, 0.0397, 0.0805],
#          [0.0457, 0.0923, 0.0588, 0.0331, 0.0575],
#          [0.1034, 0.0538, 0.0537, 0.0728, 0.1149],
#          [0.0465, 0.0692, 0.0742, 0.0265, 0.0460],
#          [0.1611, 0.2231, 0.2046, 0.2417, 0.1609],
#          [0.0681, 0.0538, 0.0818, 0.0464, 0.0575],
#          [0.1010, 0.1692, 0.1279, 0.0662, 0.1379],
#          [0.0833, 0.0308, 0.0486, 0.1192, 0.1034],
#          [0.1458, 0.0692, 0.0870, 0.1589, 0.1034],
#          [0.0625, 0.1538, 0.1125, 0.0993, 0.0920]], dtype=torch.float64),
#  'DET': tensor([[0.0352, 0.0469, 0.0495, 0.0448, 0.0633],
#          [0.0989, 0.0391, 0.0599, 0.0933, 0.0633],
#          [0.0188, 0.0156, 0.0260, 0.0858, 0.0380],
#          [0.1415, 0.4219, 0.2656, 0.0522, 0.2152],
#          [0.0687, 0.0469, 0.0391, 0.0410, 0.0633],
#          [0.2003, 0.1016, 0.1615, 0.2015, 0.0886],
#          [0.1259, 0.0391, 0.0547, 0.1567, 0.0886],
#          [0.0613, 0.0391, 0.0807, 0.0485, 0.1266],
#          [0.0793, 0.0156, 0.0703, 0.0672, 0.0506],
#          [0.0311, 0.0547, 0.0443, 0.0112, 0.0380],
#          [0.0319, 0.1172, 0.0625, 0.0485, 0.0633],
#          [0.0343, 0.0313, 0.0286, 0.0149, 0.0380],
#          [0.0728, 0.0313, 0.0573, 0.1343, 0.0633]], dtype=torch.float64),
#  'GSW': tensor([[0.0276, 0.0842, 0.0522, 0.0351, 0.0385],
#          [0.0578, 0.0316, 0.0495, 0.0511, 0.0385],
#          [0.2286, 0.0737, 0.1291, 0.1661, 0.1667],
#          [0.2178, 0.0421, 0.1621, 0.1885, 0.0897],
#          [0.0620, 0.0947, 0.1758, 0.2204, 0.1795],
#          [0.0477, 0.0737, 0.0824, 0.1022, 0.1154],
#          [0.0528, 0.1053, 0.0824, 0.0415, 0.0513],
#          [0.0335, 0.0737, 0.0330, 0.0575, 0.0641],
#          [0.0528, 0.2526, 0.0769, 0.0479, 0.0769],
#          [0.0394, 0.1158, 0.0632, 0.0128, 0.0385],
#          [0.1801, 0.0526, 0.0934, 0.0767, 0.1410]], dtype=torch.float64),
#  'HOU': tensor([[0.1429, 0.4583, 0.2579, 0.0583, 0.0795],
#          [0.0250, 0.0521, 0.0566, 0.0167, 0.0455],
#          [0.1394, 0.0312, 0.0597, 0.0792, 0.0682],
#          [0.0792, 0.0417, 0.0660, 0.0208, 0.0568],
#          [0.3107, 0.0833, 0.1824, 0.3125, 0.2273],
#          [0.0310, 0.0833, 0.0660, 0.0250, 0.0455],
#          [0.1343, 0.0625, 0.1226, 0.3417, 0.2273],
#          [0.0749, 0.0312, 0.0503, 0.0958, 0.0682],
#          [0.0628, 0.1562, 0.1384, 0.0500, 0.1818]], dtype=torch.float64),
#  'IND': tensor([[0.1690, 0.0408, 0.1085, 0.0784, 0.1111],
#          [0.1052, 0.0510, 0.0762, 0.2353, 0.1728],
#          [0.0958, 0.0510, 0.0704, 0.0941, 0.0988],
#          [0.0554, 0.0102, 0.0352, 0.0667, 0.0494],
#          [0.0610, 0.0510, 0.0850, 0.1529, 0.1358],
#          [0.0366, 0.0714, 0.0411, 0.0157, 0.0247],
#          [0.0685, 0.0204, 0.0352, 0.0353, 0.0247],
#          [0.0329, 0.0612, 0.0587, 0.0471, 0.0247],
#          [0.1324, 0.2551, 0.1994, 0.1137, 0.0741],
#          [0.1249, 0.1429, 0.1701, 0.0627, 0.0988],
#          [0.1183, 0.2449, 0.1202, 0.0980, 0.1852]], dtype=torch.float64),
#  'LAC': tensor([[0.0643, 0.1124, 0.1105, 0.1520, 0.1343],
#          [0.0694, 0.0787, 0.0552, 0.0800, 0.0896],
#          [0.1675, 0.0899, 0.1464, 0.1040, 0.1045],
#          [0.0914, 0.0787, 0.0580, 0.1320, 0.1791],
#          [0.0423, 0.1573, 0.1133, 0.0560, 0.0149],
#          [0.1404, 0.2472, 0.1188, 0.0800, 0.1343],
#          [0.1768, 0.0787, 0.1989, 0.1080, 0.1045],
#          [0.0406, 0.0562, 0.0801, 0.0320, 0.0448],
#          [0.0085, 0.0112, 0.0166, 0.0120, 0.0299],
#          [0.0296, 0.0337, 0.0359, 0.0280, 0.0448],
#          [0.1692, 0.0562, 0.0663, 0.2160, 0.1194]], dtype=torch.float64),
#  'LAL': tensor([[0.0763, 0.1009, 0.0966, 0.1593, 0.1685],
#          [0.0878, 0.0550, 0.0529, 0.0383, 0.1011],
#          [0.0239, 0.1651, 0.0874, 0.0177, 0.0449],
#          [0.0601, 0.0459, 0.0736, 0.0413, 0.1124],
#          [0.1410, 0.0734, 0.0989, 0.0885, 0.0562],
#          [0.2111, 0.0917, 0.1701, 0.2448, 0.1461],
#          [0.1441, 0.0826, 0.1057, 0.0737, 0.0674],
#          [0.0924, 0.2385, 0.1126, 0.0206, 0.0674],
#          [0.0709, 0.0642, 0.1034, 0.2360, 0.1348],
#          [0.0555, 0.0459, 0.0621, 0.0619, 0.0674],
#          [0.0370, 0.0367, 0.0368, 0.0177, 0.0337]], dtype=torch.float64),
#  'MEM': tensor([[0.0740, 0.1100, 0.1267, 0.1176, 0.1413],
#          [0.1952, 0.0600, 0.0755, 0.2510, 0.1413],
#          [0.1452, 0.1100, 0.2022, 0.1843, 0.1196],
#          [0.0907, 0.1800, 0.1186, 0.0353, 0.0870],
#          [0.0879, 0.0600, 0.0782, 0.0549, 0.1304],
#          [0.1277, 0.1300, 0.0916, 0.0431, 0.0978],
#          [0.0731, 0.0300, 0.0431, 0.1333, 0.0870],
#          [0.0657, 0.1400, 0.1159, 0.0824, 0.0543],
#          [0.0537, 0.1400, 0.0755, 0.0431, 0.0326],
#          [0.0870, 0.0400, 0.0728, 0.0549, 0.1087]], dtype=torch.float64),
#  'MIA': tensor([[0.0738, 0.1575, 0.1328, 0.0800, 0.1034],
#          [0.0647, 0.0315, 0.0702, 0.0909, 0.0690],
#          [0.0896, 0.0315, 0.0576, 0.0909, 0.1034],
#          [0.0580, 0.1260, 0.0602, 0.0218, 0.0920],
#          [0.0630, 0.0709, 0.0677, 0.0618, 0.0575],
#          [0.0829, 0.0709, 0.0952, 0.0655, 0.0805],
#          [0.1376, 0.0551, 0.0727, 0.1491, 0.1264],
#          [0.1244, 0.0787, 0.0752, 0.1527, 0.0920],
#          [0.0995, 0.0157, 0.0627, 0.1018, 0.0805],
#          [0.1020, 0.2835, 0.1955, 0.0291, 0.0690],
#          [0.1045, 0.0787, 0.1103, 0.1564, 0.1264]], dtype=torch.float64),
#  'MIL': tensor([[0.2152, 0.2178, 0.2362, 0.2077, 0.1585],
#          [0.1235, 0.1089, 0.0826, 0.1937, 0.1829],
#          [0.1212, 0.0990, 0.0803, 0.1127, 0.0854],
#          [0.0497, 0.0495, 0.0619, 0.0493, 0.0488],
#          [0.0536, 0.0990, 0.0734, 0.0704, 0.0610],
#          [0.0528, 0.0594, 0.0459, 0.0739, 0.1098],
#          [0.0528, 0.1386, 0.0711, 0.0282, 0.0610],
#          [0.0971, 0.0396, 0.1032, 0.0423, 0.0732],
#          [0.1422, 0.0594, 0.1216, 0.1514, 0.1220],
#          [0.0466, 0.0396, 0.0390, 0.0317, 0.0488],
#          [0.0451, 0.0891, 0.0849, 0.0387, 0.0488]], dtype=torch.float64),
#  'MIN': tensor([[0.0534, 0.0940, 0.0872, 0.0314, 0.0732],
#          [0.0901, 0.2137, 0.1192, 0.0418, 0.0976],
#          [0.0575, 0.0256, 0.0465, 0.1672, 0.1463],
#          [0.0642, 0.0513, 0.0698, 0.0418, 0.1463],
#          [0.1501, 0.0513, 0.0610, 0.1498, 0.0732],
#          [0.0876, 0.1282, 0.1134, 0.0523, 0.0732],
#          [0.1009, 0.0342, 0.0610, 0.2857, 0.1220],
#          [0.0417, 0.0171, 0.0727, 0.0244, 0.0366],
#          [0.2035, 0.2906, 0.2616, 0.1185, 0.1098],
#          [0.1510, 0.0940, 0.1076, 0.0871, 0.1220]], dtype=torch.float64),
#  'NOP': tensor([[0.0467, 0.0139, 0.0287, 0.0424, 0.0404],
#          [0.1804, 0.2153, 0.1965, 0.1034, 0.1616],
#          [0.0418, 0.0833, 0.0883, 0.0133, 0.0505],
#          [0.0348, 0.0486, 0.0486, 0.1167, 0.0505],
#          [0.0299, 0.0556, 0.0508, 0.0345, 0.0505],
#          [0.1476, 0.0764, 0.0861, 0.2042, 0.1616],
#          [0.0564, 0.0278, 0.0397, 0.0292, 0.0404],
#          [0.0571, 0.0139, 0.0375, 0.0557, 0.0606],
#          [0.0829, 0.0486, 0.0375, 0.0504, 0.0808],
#          [0.0571, 0.0972, 0.0728, 0.0186, 0.0303],
#          [0.0738, 0.0833, 0.0905, 0.2016, 0.1010],
#          [0.1490, 0.1528, 0.1435, 0.0822, 0.0707],
#          [0.0425, 0.0833, 0.0795, 0.0477, 0.1010]], dtype=torch.float64),
#  'NYK': tensor([[0.0863, 0.0379, 0.0752, 0.0822, 0.1000],
#          [0.1540, 0.0455, 0.0704, 0.1233, 0.1125],
#          [0.0710, 0.0379, 0.0874, 0.0685, 0.1250],
#          [0.1129, 0.2955, 0.1602, 0.0868, 0.0500],
#          [0.1032, 0.0606, 0.0898, 0.0502, 0.0750],
#          [0.0565, 0.0455, 0.0558, 0.0548, 0.0750],
#          [0.1194, 0.0455, 0.0680, 0.1781, 0.0875],
#          [0.0460, 0.0227, 0.0413, 0.1279, 0.0875],
#          [0.0589, 0.2045, 0.0898, 0.0274, 0.1000],
#          [0.0363, 0.0379, 0.0510, 0.0274, 0.0500],
#          [0.0879, 0.0379, 0.0631, 0.0868, 0.0500],
#          [0.0677, 0.1288, 0.1481, 0.0868, 0.0875]], dtype=torch.float64),
#  'OKC': tensor([[0.1188, 0.3740, 0.1250, 0.0661, 0.1562],
#          [0.0316, 0.0534, 0.0326, 0.0124, 0.0417],
#          [0.0590, 0.0305, 0.0408, 0.0413, 0.0521],
#          [0.2393, 0.1069, 0.1848, 0.1694, 0.2292],
#          [0.1162, 0.0916, 0.1087, 0.0413, 0.0833],
#          [0.0342, 0.0153, 0.0462, 0.0124, 0.0312],
#          [0.0419, 0.1221, 0.0707, 0.0248, 0.0938],
#          [0.0308, 0.0534, 0.0462, 0.0207, 0.0312],
#          [0.1325, 0.0382, 0.0842, 0.1694, 0.0833],
#          [0.1957, 0.1145, 0.2609, 0.4421, 0.1979]], dtype=torch.float64),
#  'ORL': tensor([[0.0991, 0.0424, 0.0505, 0.1949, 0.0833],
#          [0.0525, 0.1186, 0.0909, 0.0294, 0.0417],
#          [0.0406, 0.1356, 0.0556, 0.0294, 0.0556],
#          [0.1279, 0.0424, 0.0682, 0.1324, 0.1250],
#          [0.1355, 0.1441, 0.1439, 0.1360, 0.0972],
#          [0.0356, 0.0254, 0.0328, 0.0956, 0.0972],
#          [0.0813, 0.1102, 0.1061, 0.0404, 0.1111],
#          [0.0423, 0.0424, 0.0556, 0.0404, 0.0556],
#          [0.0229, 0.0254, 0.0379, 0.0147, 0.0139],
#          [0.1279, 0.0254, 0.0783, 0.0625, 0.1250],
#          [0.0584, 0.0508, 0.0480, 0.0846, 0.0556],
#          [0.1761, 0.2373, 0.2323, 0.1397, 0.1389]], dtype=torch.float64),
#  'PHI': tensor([[0.0401, 0.1000, 0.0746, 0.0332, 0.0541],
#          [0.1553, 0.1727, 0.0939, 0.1476, 0.2432],
#          [0.2346, 0.2273, 0.3066, 0.1365, 0.0946],
#          [0.0333, 0.0818, 0.0552, 0.0443, 0.0405],
#          [0.0495, 0.0273, 0.0525, 0.0406, 0.0811],
#          [0.0546, 0.0364, 0.0525, 0.1255, 0.1351],
#          [0.0631, 0.1000, 0.0884, 0.0480, 0.0541],
#          [0.1544, 0.0273, 0.0608, 0.0996, 0.0541],
#          [0.0708, 0.0273, 0.0331, 0.0406, 0.0541],
#          [0.1442, 0.2000, 0.1823, 0.2841, 0.1892]], dtype=torch.float64),
#  'PHO': tensor([[0.1373, 0.3333, 0.2185, 0.0684, 0.0947],
#          [0.0421, 0.0753, 0.0985, 0.0456, 0.0421],
#          [0.2241, 0.0645, 0.1077, 0.2586, 0.0947],
#          [0.0699, 0.0753, 0.0769, 0.0798, 0.1684],
#          [0.0666, 0.0108, 0.0369, 0.1369, 0.0526],
#          [0.0522, 0.0323, 0.0369, 0.0190, 0.0526],
#          [0.0691, 0.1720, 0.0954, 0.0342, 0.0632],
#          [0.0969, 0.0860, 0.1108, 0.0875, 0.0947],
#          [0.0421, 0.0538, 0.0677, 0.1217, 0.1474],
#          [0.0480, 0.0215, 0.0492, 0.0913, 0.0632],
#          [0.1516, 0.0753, 0.1015, 0.0570, 0.1263]], dtype=torch.float64),
#  'POR': tensor([[0.0781, 0.1167, 0.1597, 0.0528, 0.1143],
#          [0.0548, 0.1167, 0.0733, 0.0366, 0.0429],
#          [0.0656, 0.0333, 0.0340, 0.0366, 0.0714],
#          [0.0640, 0.1083, 0.0838, 0.0488, 0.1571],
#          [0.0631, 0.0667, 0.0602, 0.0285, 0.0571],
#          [0.0490, 0.0667, 0.0785, 0.0488, 0.0286],
#          [0.2143, 0.0750, 0.0995, 0.2805, 0.1571],
#          [0.1744, 0.0750, 0.0812, 0.1220, 0.1143],
#          [0.1296, 0.2833, 0.1832, 0.1301, 0.1429],
#          [0.0507, 0.0167, 0.0419, 0.0569, 0.0429],
#          [0.0565, 0.0417, 0.1047, 0.1585, 0.0714]], dtype=torch.float64),
#  'SAC': tensor([[0.1234, 0.2114, 0.1351, 0.0375, 0.0581],
#          [0.0795, 0.1301, 0.1108, 0.0712, 0.0814],
#          [0.1168, 0.0488, 0.0784, 0.1423, 0.1163],
#          [0.0986, 0.1789, 0.1649, 0.0899, 0.1395],
#          [0.0489, 0.0163, 0.0378, 0.0712, 0.0581],
#          [0.1433, 0.0407, 0.0865, 0.2734, 0.1860],
#          [0.0580, 0.0894, 0.0730, 0.0562, 0.0581],
#          [0.1715, 0.1057, 0.1000, 0.0936, 0.0814],
#          [0.0555, 0.0407, 0.0622, 0.0487, 0.0465],
#          [0.0307, 0.0976, 0.0811, 0.0337, 0.0465],
#          [0.0737, 0.0407, 0.0703, 0.0824, 0.1279]], dtype=torch.float64),
#  'SAS': tensor([[0.1827, 0.3263, 0.1671, 0.0934, 0.0781],
#          [0.0901, 0.0211, 0.0630, 0.0661, 0.0625],
#          [0.0686, 0.0316, 0.0877, 0.0506, 0.0781],
#          [0.0257, 0.0842, 0.0603, 0.0311, 0.0625],
#          [0.1818, 0.0737, 0.1452, 0.2412, 0.1719],
#          [0.1012, 0.0211, 0.0740, 0.0817, 0.0781],
#          [0.1175, 0.0947, 0.1616, 0.1012, 0.1250],
#          [0.0849, 0.0316, 0.0521, 0.1167, 0.0937],
#          [0.0472, 0.2421, 0.0822, 0.0467, 0.0625],
#          [0.0154, 0.0211, 0.0192, 0.0195, 0.0312],
#          [0.0849, 0.0526, 0.0877, 0.1518, 0.1562]], dtype=torch.float64),
#  'TOR': tensor([[0.0601, 0.1034, 0.0636, 0.0257, 0.0814],
#          [0.0884, 0.0920, 0.0970, 0.0588, 0.1047],
#          [0.1288, 0.2414, 0.1818, 0.0478, 0.0465],
#          [0.2283, 0.1494, 0.1818, 0.1213, 0.2093],
#          [0.1219, 0.0690, 0.1273, 0.3199, 0.1628],
#          [0.0738, 0.0345, 0.0636, 0.0551, 0.0814],
#          [0.1451, 0.1839, 0.1606, 0.1140, 0.1047],
#          [0.0944, 0.0345, 0.0697, 0.1765, 0.1047],
#          [0.0592, 0.0920, 0.0545, 0.0809, 0.1047]], dtype=torch.float64),
#  'UTA': tensor([[0.0996, 0.0741, 0.1046, 0.0612, 0.0899],
#          [0.0577, 0.0370, 0.0306, 0.0935, 0.0337],
#          [0.0987, 0.2500, 0.1173, 0.0432, 0.0787],
#          [0.1331, 0.3519, 0.2296, 0.0719, 0.0899],
#          [0.1013, 0.0370, 0.0918, 0.2050, 0.1348],
#          [0.0762, 0.0185, 0.0587, 0.0432, 0.0449],
#          [0.1992, 0.0741, 0.0842, 0.1511, 0.1573],
#          [0.0335, 0.0185, 0.0332, 0.0216, 0.0225],
#          [0.0435, 0.0278, 0.0816, 0.0540, 0.0787],
#          [0.1063, 0.0463, 0.0791, 0.2194, 0.1461],
#          [0.0318, 0.0185, 0.0587, 0.0180, 0.1011],
#          [0.0192, 0.0463, 0.0306, 0.0180, 0.0225]], dtype=torch.float64),
#  'WAS': tensor([[0.1495, 0.1127, 0.1692, 0.1659, 0.1690],
#          [0.2715, 0.1549, 0.1466, 0.2402, 0.2113],
#          [0.0509, 0.0986, 0.0789, 0.0655, 0.0563],
#          [0.1113, 0.2254, 0.1767, 0.0568, 0.0423],
#          [0.1304, 0.0986, 0.1241, 0.0786, 0.0845],
#          [0.1336, 0.1408, 0.1767, 0.0873, 0.2254],
#          [0.0583, 0.0282, 0.0338, 0.0873, 0.0704],
#          [0.0944, 0.1408, 0.0940, 0.2183, 0.1408]], dtype=torch.float64)}

# %%
data_index = {}

for team in team_list:
    
    try:

        data_row_max = data[team].max(axis=1).values
        N = len(data_row_max)
        index = ((data_row_max-torch.ones(N))/N).sum()
        data_index[team] = index.item()
        
    except:
        pass

# %%
pl = list(data_index.values())
x = np.zeros(len(pl))

# %% [markdown]
# ## Collaborative Index
#
# $I(\{K\}, T) = \sum_{i=1}^{N} <K_i, T> / N$

# %%
for key in data_index:
    I = data_index[key]
    print("{}: {}".format(key, np.round(I, 3)))
# Out:
# ATL: -0.859
# BOS: -0.874
# BRK: -0.852
# CHI: -0.842
# CHO: -0.887
# CLE: -0.811
# DAL: -0.854
# DEN: -0.873
# DET: -0.873
# GSW: -0.85
# HOU: -0.806
# IND: -0.855
# LAC: -0.858
# LAL: -0.849
# MEM: -0.844
# MIA: -0.865
# MIL: -0.877
# MIN: -0.83
# NOP: -0.886
# NYK: -0.862
# OKC: -0.832
# ORL: -0.877
# PHI: -0.844
# PHO: -0.844
# POR: -0.854
# SAC: -0.859
# SAS: -0.851
# TOR: -0.828
# UTA: -0.853
# WAS: -0.822

# %% [markdown]
# ### Quartile plot for $I(y,t)$

# %%
plt.boxplot(pl, labels=["y=2019"])
plt.ylabel("I(y,t)")
# Out:
# Text(0, 0.5, 'I(y,t)')

# %% [markdown]
# ### Scatter plot for $I(y,t)$, just to see the values on the same x-axis.

# %%
plt.scatter(x, pl, marker = "+")
plt.ylabel('I(y,t)')
# Out:
# Text(0, 0.5, 'I(y,t)')

# %%
(max(pl)-min(pl))/min(pl)
# Out:
# -0.09137404244782359
